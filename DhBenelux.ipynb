# %% [markdown]
# # Koninklijke Bibliotheek
#
# ## DhBenelux2018: Mining Delpher with a Jupyter Notebook

# %% [markdown]
# # WhatWhyHow
#
# This is a simple introduction into using Python to work with plain text and XML data,
# we're not focussing on Panda's or Numpy or any external library in this introduction cource.
#
# Some code blocks contain bonus questions, like so:
#
#  ?
#   What if blah bla?
#
# Feel free to answer those questions during the workshop.
#
# Some of the rationale behind this workshop:
#
# https://www.theatlantic.com/science/archive/2018/04/the-scientific-paper-is-obsolete/556676/
#
#
# If you want to run this notebook locally make sure you can install external libs. (using pip or easy_install), if you encounter output like this: "ImportError: No module named matplotlib.pyplot" you should install it by executing the following:
#
# pip install matplotlib.  (Where matplotlib could be any external lib you are missing.)
#
# Tested with python2.7
#
#
# Workshop written by Willem Jan Faber, feel free to redistribute!

# %% [markdown]
# # Introduction data-types
#
# A data-type defines the operation you can do on data, and data defines the data-type.
#
# Overview of most important types:
#
# int, str, list, dict, boolean, set. (They don't mix)

# %%
type(1)
# Out:
# int

# %%
type(z)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-b299dae34202> in <module>()
# ----> 1 type(z)
#
# NameError: name 'z' is not defined

# %%
type("z")
# Out:
# str

# %% [markdown]
# #### Mixing types is not allowed...
#
#
# #### For what is monkey + 1?

# %%
1 + "monkey"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-a12fabb4c3d4> in <module>()
# ----> 1 1 + "monkey"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# #### Morphing from one type to other is called 'casting':

# %%
str(1) + "monkey"
# Out:
# '1monkey'

# %% [markdown]
# #### dir() and help() are usefull functions to activly explore Python, you don't have to understand all.

# %%
help(type("a"))
# Out:
# Help on class str in module __builtin__:
#
# class str(basestring)
#  |  str(object='') -> string
#  |
#  |  Return a nice string representation of the object.
#  |  If the argument is a string, the return value is the same object.
#  |
#  |  Method resolution order:
#  |      str
#  |      basestring
#  |      object
#  |
#  |  Methods defined here:
#  |
#  |  __add__(...)
#  |      x.__add__(y) <==> x+y
#  |
#  |  __contains__(...)
#  |      x.__contains__(y) <==> y in x
#  |
#  |  __eq__(...)
#  |      x.__eq__(y) <==> x==y
#  |
#  |  __format__(...)
#  |      S.__format__(format_spec) -> string
#  |
#  |      Return a formatted version of S as described by format_spec.
#  |
#  |  __ge__(...)
#  |      x.__ge__(y) <==> x>=y
#  |
#  |  __getattribute__(...)
#  |      x.__getattribute__('name') <==> x.name
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __getnewargs__(...)
#  |
#  |  __getslice__(...)
#  |      x.__getslice__(i, j) <==> x[i:j]
#  |
#  |      Use of negative indices is not supported.
#  |
#  |  __gt__(...)
#  |      x.__gt__(y) <==> x>y
#  |
#  |  __hash__(...)
#  |      x.__hash__() <==> hash(x)
#  |
#  |  __le__(...)
#  |      x.__le__(y) <==> x<=y
#  |
#  |  __len__(...)
#  |      x.__len__() <==> len(x)
#  |
#  |  __lt__(...)
#  |      x.__lt__(y) <==> x<y
#  |
#  |  __mod__(...)
#  |      x.__mod__(y) <==> x%y
#  |
#  |  __mul__(...)
#  |      x.__mul__(n) <==> x*n
#  |
#  |  __ne__(...)
#  |      x.__ne__(y) <==> x!=y
#  |
#  |  __repr__(...)
#  |      x.__repr__() <==> repr(x)
#  |
#  |  __rmod__(...)
#  |      x.__rmod__(y) <==> y%x
#  |
#  |  __rmul__(...)
#  |      x.__rmul__(n) <==> n*x
#  |
#  |  __sizeof__(...)
#  |      S.__sizeof__() -> size of S in memory, in bytes
#  |
#  |  __str__(...)
#  |      x.__str__() <==> str(x)
#  |
#  |  capitalize(...)
#  |      S.capitalize() -> string
#  |
#  |      Return a copy of the string S with only its first character
#  |      capitalized.
#  |
#  |  center(...)
#  |      S.center(width[, fillchar]) -> string
#  |
#  |      Return S centered in a string of length width. Padding is
#  |      done using the specified fill character (default is a space)
#  |
#  |  count(...)
#  |      S.count(sub[, start[, end]]) -> int
#  |
#  |      Return the number of non-overlapping occurrences of substring sub in
#  |      string S[start:end].  Optional arguments start and end are interpreted
#  |      as in slice notation.
#  |
#  |  decode(...)
#  |      S.decode([encoding[,errors]]) -> object
#  |
#  |      Decodes S using the codec registered for encoding. encoding defaults
#  |      to the default encoding. errors may be given to set a different error
#  |      handling scheme. Default is 'strict' meaning that encoding errors raise
#  |      a UnicodeDecodeError. Other possible values are 'ignore' and 'replace'
#  |      as well as any other name registered with codecs.register_error that is
#  |      able to handle UnicodeDecodeErrors.
#  |
#  |  encode(...)
#  |      S.encode([encoding[,errors]]) -> object
#  |
#  |      Encodes S using the codec registered for encoding. encoding defaults
#  |      to the default encoding. errors may be given to set a different error
#  |      handling scheme. Default is 'strict' meaning that encoding errors raise
#  |      a UnicodeEncodeError. Other possible values are 'ignore', 'replace' and
#  |      'xmlcharrefreplace' as well as any other name registered with
#  |      codecs.register_error that is able to handle UnicodeEncodeErrors.
#  |
#  |  endswith(...)
#  |      S.endswith(suffix[, start[, end]]) -> bool
#  |
#  |      Return True if S ends with the specified suffix, False otherwise.
#  |      With optional start, test S beginning at that position.
#  |      With optional end, stop comparing S at that position.
#  |      suffix can also be a tuple of strings to try.
#  |
#  |  expandtabs(...)
#  |      S.expandtabs([tabsize]) -> string
#  |
#  |      Return a copy of S where all tab characters are expanded using spaces.
#  |      If tabsize is not given, a tab size of 8 characters is assumed.
#  |
#  |  find(...)
#  |      S.find(sub [,start [,end]]) -> int
#  |
#  |      Return the lowest index in S where substring sub is found,
#  |      such that sub is contained within S[start:end].  Optional
#  |      arguments start and end are interpreted as in slice notation.
#  |
#  |      Return -1 on failure.
#  |
#  |  format(...)
#  |      S.format(*args, **kwargs) -> string
#  |
#  |      Return a formatted version of S, using substitutions from args and kwargs.
#  |      The substitutions are identified by braces ('{' and '}').
#  |
#  |  index(...)
#  |      S.index(sub [,start [,end]]) -> int
#  |
#  |      Like S.find() but raise ValueError when the substring is not found.
#  |
#  |  isalnum(...)
#  |      S.isalnum() -> bool
#  |
#  |      Return True if all characters in S are alphanumeric
#  |      and there is at least one character in S, False otherwise.
#  |
#  |  isalpha(...)
#  |      S.isalpha() -> bool
#  |
#  |      Return True if all characters in S are alphabetic
#  |      and there is at least one character in S, False otherwise.
#  |
#  |  isdigit(...)
#  |      S.isdigit() -> bool
#  |
#  |      Return True if all characters in S are digits
#  |      and there is at least one character in S, False otherwise.
#  |
#  |  islower(...)
#  |      S.islower() -> bool
#  |
#  |      Return True if all cased characters in S are lowercase and there is
#  |      at least one cased character in S, False otherwise.
#  |
#  |  isspace(...)
#  |      S.isspace() -> bool
#  |
#  |      Return True if all characters in S are whitespace
#  |      and there is at least one character in S, False otherwise.
#  |
#  |  istitle(...)
#  |      S.istitle() -> bool
#  |
#  |      Return True if S is a titlecased string and there is at least one
#  |      character in S, i.e. uppercase characters may only follow uncased
#  |      characters and lowercase characters only cased ones. Return False
#  |      otherwise.
#  |
#  |  isupper(...)
#  |      S.isupper() -> bool
#  |
#  |      Return True if all cased characters in S are uppercase and there is
#  |      at least one cased character in S, False otherwise.
#  |
#  |  join(...)
#  |      S.join(iterable) -> string
#  |
#  |      Return a string which is the concatenation of the strings in the
#  |      iterable.  The separator between elements is S.
#  |
#  |  ljust(...)
#  |      S.ljust(width[, fillchar]) -> string
#  |
#  |      Return S left-justified in a string of length width. Padding is
#  |      done using the specified fill character (default is a space).
#  |
#  |  lower(...)
#  |      S.lower() -> string
#  |
#  |      Return a copy of the string S converted to lowercase.
#  |
#  |  lstrip(...)
#  |      S.lstrip([chars]) -> string or unicode
#  |
#  |      Return a copy of the string S with leading whitespace removed.
#  |      If chars is given and not None, remove characters in chars instead.
#  |      If chars is unicode, S will be converted to unicode before stripping
#  |
#  |  partition(...)
#  |      S.partition(sep) -> (head, sep, tail)
#  |
#  |      Search for the separator sep in S, and return the part before it,
#  |      the separator itself, and the part after it.  If the separator is not
#  |      found, return S and two empty strings.
#  |
#  |  replace(...)
#  |      S.replace(old, new[, count]) -> string
#  |
#  |      Return a copy of string S with all occurrences of substring
#  |      old replaced by new.  If the optional argument count is
#  |      given, only the first count occurrences are replaced.
#  |
#  |  rfind(...)
#  |      S.rfind(sub [,start [,end]]) -> int
#  |
#  |      Return the highest index in S where substring sub is found,
#  |      such that sub is contained within S[start:end].  Optional
#  |      arguments start and end are interpreted as in slice notation.
#  |
#  |      Return -1 on failure.
#  |
#  |  rindex(...)
#  |      S.rindex(sub [,start [,end]]) -> int
#  |
#  |      Like S.rfind() but raise ValueError when the substring is not found.
#  |
#  |  rjust(...)
#  |      S.rjust(width[, fillchar]) -> string
#  |
#  |      Return S right-justified in a string of length width. Padding is
#  |      done using the specified fill character (default is a space)
#  |
#  |  rpartition(...)
#  |      S.rpartition(sep) -> (head, sep, tail)
#  |
#  |      Search for the separator sep in S, starting at the end of S, and return
#  |      the part before it, the separator itself, and the part after it.  If the
#  |      separator is not found, return two empty strings and S.
#  |
#  |  rsplit(...)
#  |      S.rsplit([sep [,maxsplit]]) -> list of strings
#  |
#  |      Return a list of the words in the string S, using sep as the
#  |      delimiter string, starting at the end of the string and working
#  |      to the front.  If maxsplit is given, at most maxsplit splits are
#  |      done. If sep is not specified or is None, any whitespace string
#  |      is a separator.
#  |
#  |  rstrip(...)
#  |      S.rstrip([chars]) -> string or unicode
#  |
#  |      Return a copy of the string S with trailing whitespace removed.
#  |      If chars is given and not None, remove characters in chars instead.
#  |      If chars is unicode, S will be converted to unicode before stripping
#  |
#  |  split(...)
#  |      S.split([sep [,maxsplit]]) -> list of strings
#  |
#  |      Return a list of the words in the string S, using sep as the
#  |      delimiter string.  If maxsplit is given, at most maxsplit
#  |      splits are done. If sep is not specified or is None, any
#  |      whitespace string is a separator and empty strings are removed
#  |      from the result.
#  |
#  |  splitlines(...)
#  |      S.splitlines(keepends=False) -> list of strings
#  |
#  |      Return a list of the lines in S, breaking at line boundaries.
#  |      Line breaks are not included in the resulting list unless keepends
#  |      is given and true.
#  |
#  |  startswith(...)
#  |      S.startswith(prefix[, start[, end]]) -> bool
#  |
#  |      Return True if S starts with the specified prefix, False otherwise.
#  |      With optional start, test S beginning at that position.
#  |      With optional end, stop comparing S at that position.
#  |      prefix can also be a tuple of strings to try.
#  |
#  |  strip(...)
#  |      S.strip([chars]) -> string or unicode
#  |
#  |      Return a copy of the string S with leading and trailing
#  |      whitespace removed.
#  |      If chars is given and not None, remove characters in chars instead.
#  |      If chars is unicode, S will be converted to unicode before stripping
#  |
#  |  swapcase(...)
#  |      S.swapcase() -> string
#  |
#  |      Return a copy of the string S with uppercase characters
#  |      converted to lowercase and vice versa.
#  |
#  |  title(...)
#  |      S.title() -> string
#  |
#  |      Return a titlecased version of S, i.e. words start with uppercase
#  |      characters, all remaining cased characters have lowercase.
#  |
#  |  translate(...)
#  |      S.translate(table [,deletechars]) -> string
#  |
#  |      Return a copy of the string S, where all characters occurring
#  |      in the optional argument deletechars are removed, and the
#  |      remaining characters have been mapped through the given
#  |      translation table, which must be a string of length 256 or None.
#  |      If the table argument is None, no translation is applied and
#  |      the operation simply removes the characters in deletechars.
#  |
#  |  upper(...)
#  |      S.upper() -> string
#  |
#  |      Return a copy of the string S converted to uppercase.
#  |
#  |  zfill(...)
#  |      S.zfill(width) -> string
#  |
#  |      Pad a numeric string S with zeros on the left, to fill a field
#  |      of the specified width.  The string S is never truncated.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __new__ = <built-in method __new__ of type object>
#  |      T.__new__(S, ...) -> a new object with type S, a subtype of T

# %% [markdown]
# ### The boolean type

# %%
True == True # Built into the language as True and False, these words represent 1 , 0 state.
# Out:
# True

# %%
if True: print("ok")
# Out:
# ok

# %%
if False: print("ok")

# %%
True or False
# Out:
# True

# %% [markdown]
# ### The dictonary type

# %%
a = {}
print(type(a))
# Out:
# <type 'dict'>

# %%
print(dir(type(a)))
# Out:
# ['__class__', '__cmp__', '__contains__', '__delattr__', '__delitem__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'has_key', 'items', 'iteritems', 'iterkeys', 'itervalues', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values', 'viewitems', 'viewkeys', 'viewvalues']

# %%
a = {"fruit": 1,
     "groente" : 2,
     "vlees" : 3}
print(a["vlees"])
# Out:
# 3

# %%
a.get("vlees")
# Out:
# 3

# %%
for i in a:
    print(i)
# Out:
# groente
# fruit
# vlees

# %%
for i in a:
    print(i, a.get(i))
# Out:
# ('groente', 2)
# ('fruit', 1)
# ('vlees', 3)

# %% [markdown]
# ### The list type

# %%
b = []
print(type(b))
# Out:
# <class 'list'>

# %%
print(dir(type(b)))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
b.append(1)
b.append(2)
b.append(9)
b.append(-1)
b.append(2)
print(b)
# Out:
# [1, 2, 9, -1, 2]

# %% [markdown]
# List's can be used to sort.

# %%
print(sorted(b)) # Sort on printing, don't touch the list.
b.sort() # Sort the list in memory.
print(b)
# Out:
# [-1, 1, 2, 2, 9]
# [-1, 1, 2, 2, 9]

# %% [markdown]
# Addressing the list using position of element.

# %%
print(b[0]) # First element
print(b[-1]) # Print the last element
# Out:
# -1
# 9

# %% [markdown]
# Using this type of adressing to select a range.

# %%
print(b[0:2]) # Everything from the first element till the 2nd.
# Out:
# [-1, 1]

# %% [markdown]
# Looping over a list.

# %%
for i in b: # Simple for loop
    print(i)
    
    #
    # ?
    # Try to loop over a range of the list, without using a extra line of code.
# Out:
# -1
# 1
# 2
# 2
# 9

# %% [markdown]
# List's are often found nested, with a filter expression.

# %%
print([i for i in b if i > 0])
# Out:
# [1, 2, 2, 9]

# %% [markdown]
# Query a list

# %%
print(10 in b)
# Out:
# False

# %% [markdown]
# ### The set type

# %%
a = set([1,1,2,2,2,2,2,3,4]) # A list of numbers is casted into a set.
print(a) # Set's only contain unique items.
# Out:
# {1, 2, 3, 4}

# %%
print(dir(type(a)))
# Out:
# ['__and__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__iand__', '__init__', '__ior__', '__isub__', '__iter__', '__ixor__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__rand__', '__reduce__', '__reduce_ex__', '__repr__', '__ror__', '__rsub__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__xor__', 'add', 'clear', 'copy', 'difference', 'difference_update', 'discard', 'intersection', 'intersection_update', 'isdisjoint', 'issubset', 'issuperset', 'pop', 'remove', 'symmetric_difference', 'symmetric_difference_update', 'union', 'update']

# %%
b = set([2,3,5,9])
a.union(b)
# Out:
# {1, 2, 3, 4, 5, 9}

# %%
a.intersection(b)
# Out:
# {2, 3}

# %%
#
# ?
# Now you understand the basic types, can you combine and work with them?
# For example:

# a = [{'gluten' : 'vrij', 'verkocht' : False}, {'water' : 'stroom', 'verkocht' : True}]

# %% [markdown]
# ### Operations on data

# %%
1 + 1 # Adding
# Out:
# 2

# %%
a = 1 + 1 # Using variable names
b = a + 1
b
# Out:
# 3

# %%
10 / 2 # Divide
# Out:
# 5.0

# %%
2 * 8 # Multiply
# Out:
# 16

# %%
len("Dit is een str")
# Out:
# 14

# %%
len([1,2,3])
# Out:
# 3

# %%
"HOOFDLETTER".isupper()
# Out:
# True

# %%
"pindakaas".endswith("kaas")
# Out:
# True

# %%
"A".isalpha() # Alphanumeric?
# Out:
# True

# %%
"$sdew#@gfdsfgd$#@".isalpha()
# Out:
# False

# %%
a = "b" # Comparing types of data is seen often.
b = "b"
type(a) == type(b)
# Out:
# True

# %%
type([]) == type("")
# Out:
# False

# %% [markdown]
# [Now let's apply](https://www.youtube.com/watch?v=dQw4w9WgXcQ)

# %% [markdown]
# # Working with data from disk
# https://resolver.kb.nl/resolve?urn=DATA:kranten:kranten_pd_171x.zip
#
# This file was downloaded and unzipped in the directory data, let's explore.

# %%
import os # External library to interact with operating system

os.listdir('data')
# Out:
# ['index_kranten_pd_171x.tsv',
#  '1713',
#  'README_newspapers_pd_171x.txt',
#  '1719',
#  'resolve?urn=DATA:kranten:kranten_pd_171x.zip',
#  '1717',
#  '1718',
#  '1714',
#  '1710',
#  '1716',
#  'LEESMIJ_kranten_pd_171x.txt',
#  '1712',
#  '1715',
#  '1711']

# %%
os.listdir('data/1717')
# Out:
# ['12', '06', '08', '07', '11', '03', '04', '02', '01', '10', '05', '09']

# %%
for file in os.listdir('data/1717/01/14/DDD_ddd_011105149_mpeg21'):
    if file.endswith('_articletext.xml'):
        print(file)
# Out:
# DDD_011105149_0003_articletext.xml
# DDD_011105149_0001_articletext.xml
# DDD_011105149_0004_articletext.xml
# DDD_011105149_0006_articletext.xml
# DDD_011105149_0002_articletext.xml
# DDD_011105149_0005_articletext.xml

# %% [markdown]
# ## Load OCR text into memory for exploration.

# %%
article_text = [] # Initialize empy list for article text.
PATH = 'data/1717/01/14/DDD_ddd_011105149_mpeg21'

for file in os.listdir(PATH):
    if file.endswith('_articletext.xml'):
        with open(PATH + os.sep + file, 'r') as fh:
            article_text.append(fh.read())

print(article_text[0])
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <text>
# 	<title>Duytflant en d&apos;aengrenfende Rijcken.</title>
# 	<p>écu *7 December. - Schootf t&amp;gielijcks meei , leerde tot het aennetnen rari&apos;de Recrutcn herwicrts koitfem ni-t jls&quot;«» lid jCcV fijhênt VaiCAfc**«Je*i tftir WvttcAibérg $&gt;M ■ 4 iisi&amp;i 4 c»-r.&apos;:&gt;:r !:&lt;</p>
# 	<p>• •»/ - * ■ * . &apos;■ j ,\ . l o 7 &apos; . r». * - ?-4» ÏCnneral 491 ; Bevern 574, LefFeïholtzj jj j Leopold Lêthiringen 735 , Franfois Lottharirigen 707 ,-&apos;en Luvingftein 620&apos;, tc famen 6518 Man. • . . • . . , Regensburg den 30 December. Wegens de Feeftdagen is in de publjjckc Saken niets voorgevallen.&apos; Het Compliment vaii Congratulatic by den Keyferl. Principacl-Cbmmiflaris is wegens fijn Indifpofitie.eerft op den 26 door &apos;t Ceur-Mentfis-Direttorium afgelegt. De Vórftelijckc correfpondereridc Gefanten continueren nog ha&apos;cr Conferentien; öm ecn middel uyt te vindon , hoe fy hèt Ceremonieel roet den Keyferl. Principael-CotHmiflaris beter füllen overeenkomen ;&gt; en van dc Cavaliers ; die fy laetft Alleen Hoóg-geëerdfte Heeren génocmt hebben , beter onthael mochten bekomen. Dog wijl het :gecnc dc Heer-.Principacl-Commilfarls laetft by fijn acnkotnft gcobfervccrt heeft, door &apos;t Keyferl. Hof wel aen de hand&apos;mogt gegeven zijn } foo moet men fien, of en hoe verre de corrclpóndexeiidc Gefanten hier in fullcn reufleren. Zedert den 22 is de Rijcks-Raed gefloten geweeft , maer mogt wel cetftdaegs wc&apos;er geopent, en als dan &apos;t Befluyt over dc laetfte Mccké-1 lcnburg-Strelitfe Memorie afgedaen werden.&apos; De reden dat defe Saeck niat voor de Feeftdagen heeft kunnen ten eynde gtfwcrdeii , wil men tocfchrijvcn, dat dc Ceur- en Vorftclijke : Dire&amp;orien &apos;t Ccurvorftelijk Befluyt,&apos;t geen in al de 3 Rijks Collegien gcapprobcert is , gaerne in forme van een Rijcks-Goedachten geichickt wilde hebben: Doch wijl by de tijtel van&apos;den Heer Cardinael d&apos;Augsburgfe Confeifions verwante Gefatiteri tót dc exprelfie , des H. Apoffolifa Stoels, niet verftaen kunnen , foo mocht het wel in het toekomende , gelijck het voorheen met dfch Cardinael van Lamberg gewceft is. geobferveert werden j als wanneet menden dan felven het geéne in de Rijcks-Vergaderinjj gerefolvcert en befloten wierr&apos;, niet by wijfe van een Goedachten maer van een Befluyt dér 3 Collcgieh met uytlating van de&apos;gehecletijte overgeleverth;eft. - . •• &apos;&gt; Cöppenhage den 2 January. Van Elfeneut heeft men, dat de Commandeur Paulfenmet fijn Efquadre , als oock &apos;t Schip &apos;tgeen na Weft-Indiën gedeftineert was, wegens de-contrarie Wind nog in de Sond lag ; Ondcrtuflchen gelooft men j dat de Commandeur ;Tordenfchiold ~ die van Flaftrand met de by fig hebbende Schepen na Noorwegen zeylgegacn is, aldaer geluckig fal gearriveett zijn; Uyt dat&apos; Land manqueren nu 3 Poften j&apos; na wekkers aenkomft men feer verlangt, om te vernemenr den toeftandal.T eiU ,^&apos;®ock wat de Vyand mocht ondernemen; &apos; Het van Revel gekorrie en foo lang in de Schepen gelege Btood en Meel wert tegenwoordig uyt de Schepen in de Packhuyfen gebracht, alwaer ||e.t..v°°I.tcl&lt;en&apos;n 8 van fijn Czaarfle Majefteyt tot nader ordre ftl blijven. Een Ruffis Fregat van 18 Stuckeridat, in de Noord* Zee kruyftc , is by Schlit vergaen, cn niet meet als de Capitèyn daervangefalveett. . . . ,B.crliin &lt;*&lt;« 4 JalW»ry,* De Coning heeft &lt;£e Mdrckgravin Philippine tot Coadjutrice. yari Erfurth verklaerf . &apos;t welck een Revenu van 12000 Rijcksdaeldcrs ,&apos;s jiers foude .opbrengen. , Na fcherp onderfoeck zijn 2 van&apos; de Perfonen , die de laetft gemelde Gefchriften aen de Lantaern-Palcn geaffigeert hebben , ontdeckt» Waer van d&apos;eeiie een Trompetter by wijlen deri&apos; Coning gewceft is: Sy zijn na de Huys-Vogdy gebracht en hebben bekent, dat &quot;8 een gehcele Troup van dat Volck hier onthield; waer na fterek geinquireert wert. : ... • ,• Hamburg den 8 Januaty. Van P&lt;;tersbürg heeft men confirmatie , daf doót de Storm pdie meri den 21 November gehad heeft; de tot Revel leggende CzaarfTe Vloot feer gelededl.heeft, cn dit nier alleen de Hjven feer befchadigt en de Bafttöds met het Canon weggefpoelt waren , mact ,&apos;dat odek 7 van dé befte Oorloglchépen foodartig waren ontraniponeert # dat fy b&apos;cfwac ...
# </text>

# %% [markdown]
# ## Removing XML tags for the text.

# %%
for count, article in enumerate(article_text):
    clean_article = article.replace('<?xml version="1.0" encoding="UTF-8"?>', '')
    clean_article = clean_article.replace('<text>', '')
    clean_article = clean_article.replace('</text>',  '')
    clean_article = clean_article.replace('<p>',  '')
    clean_article = clean_article.replace('</p>',  '')
    clean_article = clean_article.replace('</title>',  '')
    clean_article = clean_article.replace('<title>',  '')
    article_text[count] = clean_article
    
    #
    # ? 
    # I did not fix the XML & sign, can you fix it for me?
    
print(article_text[0])
# Out:
# 	Duytflant en d&apos;aengrenfende Rijcken.
# 	écu *7 December. - Schootf t&amp;gielijcks meei , leerde tot het aennetnen rari&apos;de Recrutcn herwicrts koitfem ni-t jls&quot;«» lid jCcV fijhênt VaiCAfc**«Je*i tftir WvttcAibérg $&gt;M ■ 4 iisi&amp;i 4 c»-r.&apos;:&gt;:r !:&lt;
# 	• •»/ - * ■ * . &apos;■ j ,\ . l o 7 &apos; . r». * - ?-4» ÏCnneral 491 ; Bevern 574, LefFeïholtzj jj j Leopold Lêthiringen 735 , Franfois Lottharirigen 707 ,-&apos;en Luvingftein 620&apos;, tc famen 6518 Man. • . . • . . , Regensburg den 30 December. Wegens de Feeftdagen is in de publjjckc Saken niets voorgevallen.&apos; Het Compliment vaii Congratulatic by den Keyferl. Principacl-Cbmmiflaris is wegens fijn Indifpofitie.eerft op den 26 door &apos;t Ceur-Mentfis-Direttorium afgelegt. De Vórftelijckc correfpondereridc Gefanten continueren nog ha&apos;cr Conferentien; öm ecn middel uyt te vindon , hoe fy hèt Ceremonieel roet den Keyferl. Principael-CotHmiflaris beter füllen overeenkomen ;&gt; en van dc Cavaliers ; die fy laetft Alleen Hoóg-geëerdfte Heeren génocmt hebben , beter onthael mochten bekomen. Dog wijl het :gecnc dc Heer-.Principacl-Commilfarls laetft by fijn acnkotnft gcobfervccrt heeft, door &apos;t Keyferl. Hof wel aen de hand&apos;mogt gegeven zijn } foo moet men fien, of en hoe verre de corrclpóndexeiidc Gefanten hier in fullcn reufleren. Zedert den 22 is de Rijcks-Raed gefloten geweeft , maer mogt wel cetftdaegs wc&apos;er geopent, en als dan &apos;t Befluyt over dc laetfte Mccké-1 lcnburg-Strelitfe Memorie afgedaen werden.&apos; De reden dat defe Saeck niat voor de Feeftdagen heeft kunnen ten eynde gtfwcrdeii , wil men tocfchrijvcn, dat dc Ceur- en Vorftclijke : Dire&amp;orien &apos;t Ccurvorftelijk Befluyt,&apos;t geen in al de 3 Rijks Collegien gcapprobcert is , gaerne in forme van een Rijcks-Goedachten geichickt wilde hebben: Doch wijl by de tijtel van&apos;den Heer Cardinael d&apos;Augsburgfe Confeifions verwante Gefatiteri tót dc exprelfie , des H. Apoffolifa Stoels, niet verftaen kunnen , foo mocht het wel in het toekomende , gelijck het voorheen met dfch Cardinael van Lamberg gewceft is. geobferveert werden j als wanneet menden dan felven het geéne in de Rijcks-Vergaderinjj gerefolvcert en befloten wierr&apos;, niet by wijfe van een Goedachten maer van een Befluyt dér 3 Collcgieh met uytlating van de&apos;gehecletijte overgeleverth;eft. - . •• &apos;&gt; Cöppenhage den 2 January. Van Elfeneut heeft men, dat de Commandeur Paulfenmet fijn Efquadre , als oock &apos;t Schip &apos;tgeen na Weft-Indiën gedeftineert was, wegens de-contrarie Wind nog in de Sond lag ; Ondcrtuflchen gelooft men j dat de Commandeur ;Tordenfchiold ~ die van Flaftrand met de by fig hebbende Schepen na Noorwegen zeylgegacn is, aldaer geluckig fal gearriveett zijn; Uyt dat&apos; Land manqueren nu 3 Poften j&apos; na wekkers aenkomft men feer verlangt, om te vernemenr den toeftandal.T eiU ,^&apos;®ock wat de Vyand mocht ondernemen; &apos; Het van Revel gekorrie en foo lang in de Schepen gelege Btood en Meel wert tegenwoordig uyt de Schepen in de Packhuyfen gebracht, alwaer ||e.t..v°°I.tcl&lt;en&apos;n 8 van fijn Czaarfle Majefteyt tot nader ordre ftl blijven. Een Ruffis Fregat van 18 Stuckeridat, in de Noord* Zee kruyftc , is by Schlit vergaen, cn niet meet als de Capitèyn daervangefalveett. . . . ,B.crliin &lt;*&lt;« 4 JalW»ry,* De Coning heeft &lt;£e Mdrckgravin Philippine tot Coadjutrice. yari Erfurth verklaerf . &apos;t welck een Revenu van 12000 Rijcksdaeldcrs ,&apos;s jiers foude .opbrengen. , Na fcherp onderfoeck zijn 2 van&apos; de Perfonen , die de laetft gemelde Gefchriften aen de Lantaern-Palcn geaffigeert hebben , ontdeckt» Waer van d&apos;eeiie een Trompetter by wijlen deri&apos; Coning gewceft is: Sy zijn na de Huys-Vogdy gebracht en hebben bekent, dat &quot;8 een gehcele Troup van dat Volck hier onthield; waer na fterek geinquireert wert. : ... • ,• Hamburg den 8 Januaty. Van P&lt;;tersbürg heeft men confirmatie , daf doót de Storm pdie meri den 21 November gehad heeft; de tot Revel leggende CzaarfTe Vloot feer gelededl.heeft, cn dit nier alleen de Hjven feer befchadigt en de Bafttöds met het Canon weggefpoelt waren , mact ,&apos;dat odek 7 van dé befte Oorloglchépen foodartig waren ontraniponeert # dat fy b&apos;cfwacrli ...

# %% [markdown]
# ## Counting the freq of words, and apply fiter

# %%
word_list = {}
for word in article_text[0].split(): # split() takes in a string and returns a list based upon the number of whitespaces.
    if not word in word_list:
        word_list[word] = 1
    else:
        word_list[word] += 1
#
# ?
# The split works but is a bit of a cheap solution, for words ending in . or , won't be taken into account.
# How could we fix this?
        

for word in word_list:
    if word_list[word] > 2 and word.isalpha() and len(word)> 4:
        print(word, word_list[word])
        
#
# ?
# The if expression could also be written as a nested list, how?
# Out:
# ('Schepen', 3)
# ('kunnen', 3)
# ('waren', 4)
# ('hebben', 3)
# ('wilde', 5)
# ('heeft', 4)
# ('laetft', 3)

# %% [markdown]
# Scaling up by analyzing all documents in mem.

# %%
word_list = {}
for count, text in enumerate(article_text):    
    for word in article_text[count].split():
        word = word.lower()
        if not word in word_list:
            word_list[word] = 1
        else:
            word_list[word] += 1


words_of_interest = []
for word in word_list:
    if word_list[word] > 4 and word.isalpha() and len(word)> 4:
        print(word, word_list[word])
        words_of_interest.append([word, word_list[word]])
# Out:
# ('pieter', 5)
# ('binnen', 5)
# ('foude', 5)
# ('coning', 6)
# ('alhier', 5)
# ('hebben', 10)
# ('schip', 5)
# ('wilde', 5)
# ('kunnen', 7)
# ('majefteyt', 5)
# ('heeft', 11)
# ('tegen', 6)
# ('hertog', 9)
# ('heeren', 5)
# ('waren', 10)
# ('sweden', 6)
# ('amfterdam', 5)
# ('schepen', 6)
# ('weder', 6)

# %% [markdown]
# ## Vizualizing using mathplotlib
#
# https://matplotlib.org/1.5.0/gallery.html

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import numpy as np
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-cf8efd004beb> in <module>()
# ----> 1 import matplotlib.pyplot as plt
#       2 import matplotlib.dates as dates
#       3 import numpy as np
#       4 get_ipython().magic(u'matplotlib inline')
#
# ImportError: No module named matplotlib.pyplot

# %%
words = []
freq = []

for word, count in words_of_interest:
    words.append(word)
    freq.append(count)
    
y_pos = np.arange(len(words))

error = np.random.rand(len(words))
print(error)
plt.barh(y_pos, freq, align='center', alpha=0.4)
plt.yticks(y_pos, words)
plt.xlabel('Freq')
plt.title('Simple word count graph')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-2666a7e2ebd1> in <module>()
#       6     freq.append(count)
#       7
# ----> 8 y_pos = np.arange(len(words))
#       9
#      10 error = np.random.rand(len(words))
#
# NameError: name 'np' is not defined

# %% [markdown]
# ## Declaring functions, enables layers of complexity

# %%
def traverse_dir(path): # Declaration of function with one parameter, returning 1 parameter.
    files_avail = []
    for files in os.walk(path):
        for list_file in files:
            if type(list_file) == type([]):
                for f in list_file:
                    if f.endswith('_articletext.xml'):
                        files_avail.append(files[0] + os.sep + f)
    return files_avail
files_avail = traverse_dir('data/')
print(len(files_avail))

def clean_text(text):
    clean_article = text.replace('<?xml version="1.0" encoding="UTF-8"?>', '')
    clean_article = clean_article.replace('<text>', '')
    clean_article = clean_article.replace('</text>',  '')
    clean_article = clean_article.replace('<p>',  '')
    clean_article = clean_article.replace('</p>',  '')
    clean_article = clean_article.replace('</title>',  '')
    clean_article = clean_article.replace('<title>',  '')
    return clean_article

article_text = []
for file in files_avail:
    with open(file, 'r') as fh:
        article_text.append(clean_text(fh.read()))
print(len(article_text))
print(len(article_text[0]))
# Out:
# 18571
# 18571
# 8283

# %%
# Some basic stats on the loaded files.
total_len = 0


print("Nr. of articles in mem", len(article_text))
for article in article_text:
    total_len += len(article)

# AVG length of article in characters.
print("Avg. nr of characters per article", round(total_len / len(article_text)))

# Same but now the number of words/tokens.
total_len = 0

for article in article_text:
    total_len += len(article.split())

print("Avg. nr of tokens per article: ", round(total_len / len(article_text)))
# Out:
# ('Nr. of articles in mem', 18571)
# ('Avg. nr of characters per article', 3694.0)
# ('Avg. nr of tokens per article: ', 579.0)

# %%
word_list = {}
stop_words = ['hebben', 
              'heeft', 
              'dont', 
              'voor', 
              'pour', 
              'dans', 
              'avec', 
              'zijn',
              'niet',
              'groot',
              'hier',
              'alle'
             ]

for count, text in enumerate(article_text):    
    for word in article_text[count].split():
        if word in stop_words:
            break
        word = word.lower()
        if not word in word_list:
            word_list[word] = 1
        else:
            word_list[word] += 1


words_of_interest = {}
for word in word_list:
    if word_list[word] > 500 and word.isalpha() and len(word)> 4:
        words_of_interest[word] = word_list[word]

# %%
words = []
freq = []

# Sorting a dict by value.
from collections import OrderedDict
from operator import itemgetter 
words_of_interest = OrderedDict(sorted(words_of_interest.items(), key = itemgetter(1), reverse = False))


for w in words_of_interest:
    print(w)
    words.append(w)
    freq.append(word_list[w])
    
y_pos = np.arange(len(words))

plt.barh(y_pos, freq, align='center', alpha=1)
plt.yticks(y_pos, words)
plt.xlabel('Freq')
plt.title('Simple word count graph')

plt.rcParams["figure.figsize"] =(5,20) 


plt.show()
# Out:
# paris
# tegen
# fullen
# madrid
# aldaer
# omtrent
# staten
# binnen
# dernier
# zijnde
# wegens
# prins
# weenen
# comte
# morgen
# waren
# majefteyt
# verkopen
# londen
# brieven
# hertog
# heeren
# alhier
# onder
# parijs
# coning
# graef
# werden
# andere
# dagen
# eenige
# duytflant
# groot
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-c1d4c9682912> in <module>()
#      13     freq.append(word_list[w])
#      14
# ---> 15 y_pos = np.arange(len(words))
#      16
#      17 plt.barh(y_pos, freq, align='center', alpha=1)
#
# NameError: name 'np' is not defined

# %% [markdown]
# # Working with XML data

# %%
import lxml.etree as et # As let's you rename things.
import os

with open('data/1710/01/02/DDD_ddd_011227941_mpeg21/didl.xml') as fh:
    data = et.iterparse(fh, recover=True)
    for i in data:
        item = i[1]
        if (item.tag.endswith('issued')):
            issued = item.text
        if (item.tag.endswith('date')):
            date = item.text
print(date, issued)
# Out:
# ('1710-01-02', '1662-1795')

# %%
# And now let's load all the didl files into a list

#
# ? 
# We've seen the following code before, if we used two parameters, we could re-use the function,
# can you re-write the function so it can be used here?

def traverse_dir(path):
    files_avail = []
    for files in os.walk(path):
        for list_file in files:
            if type(list_file) == type([]):
                for f in list_file:
                    if f.endswith('didl.xml'):
                        files_avail.append(files[0] + os.sep + f)
    return files_avail

all_didl = []
parser = et.XMLParser(recover=True) 

files_avail = traverse_dir('data/')
for filename in files_avail:
    with open(filename) as fh:
        data = et.parse(fh, parser=parser)
        all_didl.append(data)

newspaper_info = {}
for didl in all_didl:
    pages = []
    for item in didl.iter():
        if item.tag.endswith("title"):
            title = item.text
        if item.tag.endswith("date"):
            date = item.text
        if item.tag.endswith("nativePageNumber"):
            pages.append(item.text)
    print(title, date, pages)
# Out:
# ('Advertentie', '1713-12-12', ['1', '2'])
# ('De la Haye le 10 Decembre.', '1713-12-12', ['1', '2', '3', '4', '1', '2'])
# ('NEDERLANDEN.', '1713-12-16', ['1', '2', '3', '4'])
# ('Advertentie', '1713-12-23', ['1', '2'])
# ('Advertentie', '1713-12-28', ['1', '2'])
# ('Advertentie', '1713-12-28', ['1', '2', '3', '4'])
# ('SUPPLEMENT AUX NOUVELLES EXTRAORDINAIRES', '1713-12-29', ['1', '2', '3', '4', '1', '2'])
# ('SUPPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS.', '1713-12-26', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-12-26', ['1', '2'])
# ("LA crainte qu'on avoir d'une irruption des Turcs & des Tartares en", '1713-12-18', ['1', '2', '3', '4', '1', '2'])
# ('NEDERLANDEN.', '1713-12-30', ['1', '2', '3', '4'])
# ("LEs avis d'Allemagne d'aujourdhui ne parlent que de marches de", '1713-12-21', ['1', '2', '3', '4', '1', '2', '1', '2', '3', '4'])
# ('Advertentie', '1713-12-21', ['1', '2'])
# ('Advertentie', '1713-12-07', ['1', '2'])
# (u'ON mande de Raftad du 3. de ce mois, que le Prince Eug\xe8ne &', '1713-12-07', ['1', '2', '3', '4', '1', '2', '1', '2'])
# (u'Les Lettres de Rome du 25 Novembre dernier ajoutent \xe0 ce qui en a \xe9t\xe9 dit dans noue Gazette', '1713-12-15', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-12-14', ['1', '2'])
# ('Advertentie', '1713-12-14', ['1', '2', '3', '4'])
# (u"I Ln'eft ponint venu e\xe8t ordinairede lettres du Camp Imp\xe9rial pr\xe8s de", '1713-12-04', ['1', '2', '3', '4', '1', '2'])
# ('SUPPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS.', '1713-12-19', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-12-19', ['1', '2'])
# ('NEDERLANDEN.', '1713-12-02', ['1', '2', '3', '4'])
# ('NEDERLANDEN.', '1713-12-05', ['1', '2', '3', '4'])
# (u'Ilya des Letrres de Matare du 9 November dernier qui portent, que la pl\xfbpart des Perfonnes de', '1713-12-05', ['1', '2', '3', '4', '1', '2', '1', '2', '1', '2'])
# ('De Londres le 28 Novembre.', '1713-12-05', ['3', '4', '5', '6'])
# ('SUPPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS.', '1713-12-22', ['1', '2', '3', '4', '1', '2'])
# ('NEDERLANDEN.', '1713-12-09', ['1', '2', '3', '4'])
# ('Advertentie', '1713-06-12', ['1', '2', '3', '4', '1', '2', '1', '2'])
# ('Advertentie', '1713-06-13', ['1', '2'])
# ('SUPPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS.', '1713-06-13', ['1', '2', '3', '4', '1', '2'])
# ('SUPPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS.', '1713-06-16', ['1', '2', '3', '4', '5', '6', '7', '1'])
# ('SUPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS.', '1713-06-23', ['1', '2', '3', '4', '1', '2'])
# ('SUPPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS.', '1713-06-06', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-06-06', ['1', '2'])
# ('Advertentie', '1713-06-24', ['1', '2'])
# ('Advertentie', '1713-06-29', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-06-29', ['1', '2'])
# ('Advertentie', '1713-06-29', ['1', '2'])
# ('Advertentie', '1713-06-08', ['1', '2'])
# ('SUPLEMENT', '1713-06-08', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-06-26', ['1', '2', '3', '4', '1', '2'])
# ('SUPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS.', '1713-06-30', ['1', '2', '3', '4', '1', '2', '1', '2'])
# ('Advertentie', '1713-06-15', ['1', '2'])
# ('Advertentie', '1713-06-17', ['1', '2'])
# ('Advertentie', '1713-06-27', ['1', '2'])
# ('SUPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS.', '1713-06-27', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-06-03', ['1', '2'])
# ('SUPPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS.', '1713-06-02', ['1', '2', '3', '4', '1', '2'])
# ('SUPLEMENT', '1713-06-01', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-06-01', ['1', '2'])
# ('Advertentie', '1713-06-10', ['1', '2'])
# ('NEDERLANDEN.', '1713-06-20', ['1', '2', '3', '4'])
# ('SUPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS.', '1713-06-20', ['1', '2', '3', '4', '1', '2'])
# ('De la Haie le 4. Juin.', '1713-06-05', ['1', '2', '3', '4'])
# ('Advertentie', '1713-06-22', ['1', '2', '3', '4', '1', '2'])
# ('Roma den 3 Juny. Woensdag begaf de Paus fig uyt het Vaticaen', '1713-06-22', ['1', '2', '3', '4'])
# ('SUPPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS.', '1713-06-09', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-08-12', ['1', '2'])
# ('Advertentie', '1713-08-31', ['1', '2'])
# (u"APeine les troubles qui ont agit\xe9 la plus grande partie de l'Europe", '1713-08-28', ['1', '2', '3', '4', '1', '2', '1', '2', '1', '2', '1', '2'])
# ('Advertentie', '1713-08-24', ['1', '2'])
# (u'PAr les lettres de Rome du 5 on aprend, que le jour pr\xe9c\xe8dent, le', '1713-08-24', ['1', '2', '3', '4', '1', '2'])
# (u'De la Haye le 27 Ag\xfbt.', '1713-08-29', ['1', '2', '3', '4'])
# ('Advertentie', '1713-08-29', ['1', '2'])
# ('Advertentie', '1713-08-08', ['1', '2'])
# ('Advertentie', '1713-08-26', ['1', '2'])
# ('SUPPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS.', '1713-08-18', ['1', '2', '3', '4', '1', '2'])
# ('SUPLEMENT', '1713-08-21', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-08-15', ['1', '2'])
# (u'De la Haye le 13 Ao\xfbt.', '1713-08-15', ['1', '2', '3', '4'])
# ('Advertentie', '1713-08-17', ['1', '2'])
# ('SUPLEMENT', '1713-08-14', ['1', '2', '3', '4', '1', '2'])
# ('SUPLEMENT', '1713-08-03', ['1', '2', '3', '4', '1', '2'])
# ('SUPPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS.', '1713-08-04', ['1', '2', '3', '4', '1', '2'])
# (u'logeerden : Men wift weerzijds verlies n\xf6ch niet. Van Madrid het ft', '1713-08-19', ['1', '2', '3', '4'])
# ('Advertentie', '1713-08-01', ['1', '2'])
# ('SUPPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS.', '1713-08-01', ['1', '2', '3', '4', '1', '2'])
# (u'I"*T" Es Lettres de Naples du 1 dctcMolsporte.it, cju\'on avoit re\xe7u avis par des Lettres des Am-', '1713-08-25', ['1', '2', '3', '4', '1', '2'])
# ('Rome den 22 July. De is van fijn ongemack aen de Borft', '1713-08-10', ['1', '2', '3', '4'])
# ('Advertentie', '1713-08-05', ['1', '2'])
# ('Advertentie', '1713-08-22', ['1', '2'])
# ('SUPPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS.', '1713-08-22', ['1', '2', '3', '4', '1', '2', '1', '2'])
# ('SUPLEMENT', '1713-07-13', ['1', '2', '3', '4', '1', '2'])
# ('Roma den 24 Juny. Woensdag vertrock de Nuncius Vicentini', '1713-07-13', ['1', '2', '3', '4'])
# ('Advertentie', '1713-07-06', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-07-06', ['1', '2'])
# ('SUPPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS.', '1713-07-28', ['1', '2', '3', '4', '1', '2'])
# ('SUPLEMENT', '1713-07-24', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-07-29', ['1', '2'])
# ('Advertentie', '1713-07-08', ['1', '2'])
# ('SUPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS.', '1713-07-18', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-07-18', ['1', '2'])
# ('SUPPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS.', '1713-07-21', ['1', '2', '3', '4', '1', '2'])
# ('SUPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS.', '1713-07-07', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-07-11', ['1', '2'])
# ('SUPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS.', '1713-07-11', ['1', '2', '1', '2'])
# ('NEDERLANDEN.', '1713-07-15', ['1', '2', '3', '4'])
# ('Advertentie', '1713-07-17', ['1', '2', '3', '4'])
# ('SUPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS.', '1713-07-14', ['1', '2', '3', '4', '1', '2'])
# ('SUPLEMENT', '1713-07-27', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-07-27', ['1', '2'])
# ('Advertentie', '1713-07-03', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-07-04', ['1', '2'])
# ('Advertentie', '1713-07-01', ['1', '2'])
# ('De la Haye le 23 Juillet.', '1713-07-25', ['1', '2', '3', '4'])
# ('Advertentie', '1713-07-25', ['1', '2'])
# ('Advertentie', '1713-07-10', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-07-20', ['1', '2'])
# ('SUPLEMENT', '1713-07-20', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-07-22', ['1', '2'])
# ("A crainte d'une nouvelle guerre dans la Baffe Allemagne n'allar-", '1713-11-16', ['1', '2', '3', '4', '1', '2'])
# ('Napels den 14 October, Zondag nacht den', '1713-11-16', ['1', '2', '3', '4'])
# ('Advertentie', '1713-11-23', ['1', '2'])
# (u'QUoique les Potentats \xeentereff\xe9s aux troubles du Nord mettent', '1713-11-23', ['1', '2', '3', '4', '1', '2'])
# ('On mande de Petersbourg du 23. du mois deroier, que le Czar', '1713-11-06', ['1', '2', '3', '4', '1', '2', '1', '2'])
# ('NEDERLANDEN.', '1713-11-28', ['1', '2', '3', '4'])
# ('SUPLEMENT AUX NOUVELLES EXTRAORDNAIRES TS. DE DIVERS ENROITS. De LEIDE le 18 Novembre 1713.', '1713-11-28', ['1', '2', '3', '4', '1', '2'])
# ('SUPLEMENT AUX NOUVELLES EXTRAORDNAIRES DE DIVERS ENDROITS. De LEIDE le il Novembre I^l3', '1713-11-24', ['1', '2', '3', '4', '1', '2', '1', '2'])
# ('Advertentie', '1713-11-18', ['1', '2'])
# (u"Suivant les derniers avis d'Allenmagne, l'ouverture du Congr\xe8s de", '1713-11-30', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-11-30', ['1', '2'])
# ('De Londres le 14 Novembre.', '1713-11-21', ['1', '2', '3', '4'])
# ('Advertentie', '1713-11-21', ['1', '2'])
# ('Advertentie', '1713-11-07', ['1', '2'])
# ('Advertentie', '1713-11-07', ['1', '2', '3', '4', '1', '2'])
# ('Liffabon den 10 October, Hier is geatriveert het Schip de David,', '1713-11-11', ['1', '2', '3', '4'])
# ('Advertentie', '1713-11-17', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-11-14', ['1', '2'])
# ('Advertentie', '1713-11-14', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-11-27', ['1', '2', '3', '4'])
# ('Advertentie', '1713-11-03', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-11-04', ['1', '2'])
# ('Advertentie', '1713-11-02', ['1', '2'])
# ('PAr les lettres de Rome du 14. du mois dernier on aprend, que le', '1713-11-02', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-11-25', ['1', '2'])
# ('Advertentie', '1713-11-10', ['1', '2', '3', '4', '1', '2'])
# (u"Nonobflant les bruits qaui courent d'one n\xe9gociation entre l'Em-", '1713-11-20', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-11-09', ['1', '2'])
# ('De la Haie le 12. Mars.', '1713-03-13', ['1', '2', '3', '4'])
# ('SUPLEMENT AUX NOUVELIES EXTRAORDINAIRIS. DE DIVERS ENDROITS. SUPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS,', '1713-03-31', ['1', '2', '3', '4', '1', '2'])
# ('SUMPLEMENT A la Gazette de Rotterdam, du 16. Mars 1713.', '1713-03-16', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-03-16', ['1', '2'])
# ('Advertentie', '1713-03-23', ['1', '2'])
# ('Advertentie', '1713-03-23', ['1', '2'])
# (u'G\xe9n\xe9raux de cavalerie.', '1713-03-06', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-03-28', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-03-28', ['1', '2'])
# ('Advertentie', '1713-03-24', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-03-18', ['1', '2'])
# ('Advertentie', '1713-03-30', ['1', '2'])
# ('SUMPLEMENT A la Gazette de Rotterdam, du 30. Mars 1713.', '1713-03-30', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-03-21', ['1', '2', '3', '4', '1', '2'])
# ('NEDERLANDEN.', '1713-03-07', ['1', '2', '3', '4'])
# ('Advertentie', '1713-03-07', ['1', '2', '3', '4', '1', '2'])
# ('NEDERLANDEN.', '1713-03-11', ['1', '2', '3', '4'])
# ('Advertentie', '1713-03-17', ['1', '2', '3', '4', '1', '2'])
# ('NEDERLANDEN.', '1713-03-14', ['1', '2', '3', '4'])
# ('Advertentie', '1713-03-14', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-03-03', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-03-04', ['1', '2'])
# ('Advertentie', '1713-03-02', ['1', '2'])
# ('Advertentie', '1713-03-25', ['1', '2'])
# ('Advertentie', '1713-03-10', ['1', '2', '3', '4', '1', '2'])
# ('SUMPLEMENT A la Gazette de Rotterdam, du 23. Mars 1713.', '1713-03-20', ['1', '2', '3', '4', '1', '2'])
# ('NEDERLANDEN.', '1713-03-09', ['1', '2', '3', '4'])
# ('Advertentie', '1713-04-13', ['1', '2'])
# (u"ON ne s'entretient \xe0 Vienne que de la difgrace du Roi de Su\xe9d", '1713-04-06', ['1', '2', '3', '4', '1', '2'])
# ('Roma den 18 Maart. Den 12 is de Marquis van Suza te Napels', '1713-04-06', ['1', '2', '3', '4'])
# ('ON drcrit de Mofcou du 15 Mas, que le Senat avoit fait publier une Ordonbance, parla-', '1713-04-28', ['1', '2', '3', '4', '1', '2'])
# (u'Suivant les avis de Francfort du 19. on continue \xe0 voiturer par een une grande', '1713-04-24', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-04-29', ['1', '2'])
# ('Advertentie', '1713-04-08', ['1', '2'])
# ('SUPLEMENT AUX NOUVELIES EXTRAORDINAIRIS. DE DIVERS ENDROITS. De LEIDE le 18 Avril 1713.', '1713-04-18', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-04-18', ['1', '2'])
# ('SUPLEMENT AUX NOUVELIES EXTRAORDINAIRIS. DE DIVERS EN DROITS De LEIDE le 21 Avril 1713.', '1713-04-21', ['1', '2', '3', '4', '1', '2'])
# ('SUPLEMENT AUX NOUVELIES EXTRAORDINAIRIS. DE DIVERS ENDROITS, De LEIDE le 7 Avril 1713.', '1713-04-07', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-04-11', ['1', '2'])
# ('SUPLEMENT AUX NOUVELIES EXTRAORDINAIRIS. DE DIVERS ENDROITS. De KEUDE ke 11 Avril 1713.', '1713-04-11', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-04-15', ['1', '2'])
# ('SUPLEMENT AUX NOUVELIES EXTRAORDINAIRIS. DE DIVERS ENDROITS, De LEIDE le 14 Avril 1713.', '1713-04-14', ['1', '2', '3', '4', '1', '2'])
# (u'LEs changemens arriv\xe9s en faveor du Rot de Su\xe9de depuis Paflaire', '1713-04-27', ['1', '2', '3', '4', '1', '2'])
# ('NEDERLANDEN.', '1713-04-27', ['1', '2', '3', '4'])
# (u'LEs derni\xe8res lettres deStiific confirment les mouvemensque fe donne', '1713-04-03', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-04-04', ['1', '2'])
# ('SUPLEMENT AUX NOUVELIES EXTRAORDINAIRIS. DE DIVERS ENDROITS, De LEIDE le 4 Avril 1713.', '1713-04-04', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-04-01', ['1', '2'])
# ('Advertentie', '1713-04-25', ['1', '2'])
# ("triche l'Empire.", '1713-04-25', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-04-20', ['1', '2'])
# ('Advertentie', '1713-04-22', ['1', '2'])
# (u'SUMPLEMENT A la Gazette de Rotterdam, du 13. F\xe9vrier 1713.', '1713-02-13', ['1', '2', '3', '4', '1', '2'])
# (u'SUMPLEMENT A la Gazette de Rotterdam, du 20. F\xe9vrier 1713.', '1713-02-16', ['1', '2', '1', '2', '1', '2'])
# ('Advertentie', '1713-02-16', ['1', '2'])
# ('Parijs den 16 February. De Koning bevint fig wel, en fal eerf-', '1713-02-23', ['1', '2', '3', '4'])
# ('SUPLEMENT', '1713-02-06', ['1', '2', '3', '4', '1', '2'])
# ('NEDERLANDEN.', '1713-02-28', ['1', '2', '3', '4'])
# ("Es Lettres de Barcelone du 11 Janvier dernier portent, l'Imperatrice s'y tenoit encore ,", '1713-02-28', ['1', '2', '3', '4', '1', '2'])
# ('Es Lettres de Naples du 31 du Mois deruier Portent, quele Viceroy avoit reccu ordre de la', '1713-02-24', ['1', '2', '3', '4', '1', '2'])
# ('NEDERLANDEN.', '1713-02-18', ['1', '2', '3', '4'])
# ('NEDERLANDEN.', '1713-02-21', ['1', '2', '3', '4'])
# (u'ES Lettes de Genes du 4 de ce Mois porcent, que le als du Marquis de Monteleon \xe9teit ar', '1713-02-21', ['1', '2', '3', '4', '1', '2'])
# ('NEDERLANDEN.', '1713-02-07', ['1', '2', '3', '4'])
# ('De Viene le Janvier.', '1713-02-07', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-02-11', ['1', '2'])
# (u'Es Lettres de Florence du 28 Mois derniet partent, Eletoral de Satey \xe9tuit', '1713-02-17', ['1', '2', '3', '4', '1', '2'])
# ('NEDERLANDEN.', '1713-02-14', ['1', '2', '3', '4'])
# (u'Ly Lettres de Lisbonne du 10 Janvier dernier qui portent, que les tofres avoient \xe9\xe9rdta', '1713-02-14', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-02-27', ['1', '2', '3', '4'])
# ('Ly a des Lettes de Dutazzo en Dalmatie du 5 Janvier derniet qui portent, que le Faffa Allna.', '1713-02-03', ['1', '2', '3', '4', '1', '2'])
# ('NEDERLANDEN.', '1713-02-04', ['1', '2', '3', '4'])
# ('Advertentie', '1713-02-02', ['1', '2'])
# ('NEDERLANDEN.', '1713-02-25', ['1', '2', '3', '4'])
# (u'NOs M\xe9moires de Rome du 21 du Mois dermer ajouren \xe2 ce que nous en avons dit ailleurs,', '1713-02-10', ['1', '2'])
# ('Advertentie', '1713-02-09', ['1', '2'])
# ('SUPLEMENT', '1713-02-09', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-01-12', ['1', '2'])
# ('SUPLEMENT', '1713-01-12', ['1', '2', '3', '4', '1', '2', '1', '2'])
# ('Advertentie', '1713-01-31', ['1', '2'])
# ('SUPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS,', '1713-01-31', ['1', '2', '3', '4', '1', '2'])
# ('SUPLEMENT', '1713-01-16', ['1', '2', '3', '4', '1', '2'])
# ('SUPLEMENT', '1713-01-23', ['1', '2', '3', '4', '1', '2'])
# ('SUPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROTTS,', '1713-01-06', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-01-28', ['1', '2'])
# (u'F Gmjtantmopk le 10 D\xe9cembre.', '1713-01-24', ['1', '2', '3', '4'])
# ('Advertentie', '1713-01-24', ['1', '2'])
# ('Advertentie', '1713-01-26', ['1', '2'])
# ('Advertentie', '1713-01-21', ['1', '2'])
# ('Advertentie', '1713-01-07', ['1', '2'])
# ('Advertentie', '1713-01-17', ['1', '2'])
# ('SUPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS,', '1713-01-17', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-01-14', ['1', '2'])
# ('SUPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS,', '1713-01-27', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-01-03', ['1', '2'])
# ('SUPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS,', '1713-01-03', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-01-19', ['1', '2'])
# ('SUPLEMENT', '1713-01-19', ['1', '2', '3', '4', '1', '2'])
# ('SUPLEMENT', '1713-01-02', ['1', '2', '3', '4', '1', '2'])
# ('SUPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS,', '1713-01-10', ['1', '2', '1', '2', '1', '2', '3', '4'])
# ('Advertentie', '1713-01-10', ['1', '2'])
# ('SUPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS,', '1713-01-20', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-01-05', ['1', '2'])
# ('Advertentie', '1713-10-12', ['1', '2', '3', '4'])
# ('Roma den 13 September. Maendag wierden in een feerete Con-', '1713-10-12', ['1', '2', '3', '4'])
# ('Advertentie', '1713-10-13', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-10-31', ['1', '2'])
# ('Advertentie', '1713-10-31', ['1', '2', '3', '4', '1', '2'])
# ("Tons les avis de Pologne confirment que les Turcs n'ont pas det-", '1713-10-16', ['1', '2', '3', '4', '1', '2'])
# (u'E bruit court toujours en Allemagne, que le Prince Eug\xe8ne pour-l', '1713-10-23', ['1', '2', '3', '4', '1', '2', '3', '4'])
# ('Advertentie', '1713-10-06', ['1', '2', '1', '2'])
# ('Lifbon 26 September, Alhier is gearriveert het Genouees', '1713-10-28', ['1', '2', '3', '4'])
# ('Advertentie', '1713-10-24', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-10-24', ['1', '2'])
# ('Advertentie', '1713-10-26', ['1', '2'])
# ('Advertentie', '1713-10-21', ['1', '2'])
# ('Advertentie', '1713-10-07', ['1', '2'])
# ('Advertentie', '1713-10-17', ['1', '2', '3', '4', '1', '2'])
# ('NEDERLANDEN.', '1713-10-17', ['1', '2', '3', '4'])
# ('Advertentie', '1713-10-14', ['1', '2'])
# ('Advertentie', '1713-10-27', ['1', '2', '3', '4', '1', '2'])
# ('NEDERLANDEN.', '1713-10-03', ['1', '2', '3', '4'])
# ('Advertentie', '1713-10-03', ['1', '2', '3', '4', '1', '2'])
# ('Weenen den 7 October. Men heefi leker bericht, dat de', '1713-10-19', ['1', '2', '3', '4'])
# ('Les lenres de Rome du 3.Seotember porrent, quelques jours', '1713-10-19', ['1', '2', '3', '4', '1', '2'])
# (u"SUivant les derniers avis d'\xc9fpagne, la Cour avoit envoie ordre de", '1713-10-02', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-10-10', ['1', '2', '3', '4', '1', '2'])
# ('NEDERLANDEN.', '1713-10-10', ['1', '2', '3', '4'])
# ('Advertentie', '1713-10-20', ['1', '2', '3', '4', '1', '2'])
# ('Roma den 16 ocptcrabct. tJaei is cca auacic.laeilttt Wil van wij,', '1713-10-05', ['1', '2', '3', '4'])
# ('PEndant que le fracas des armes fe fait retentir en Allemagne, le', '1713-10-05', ['1', '2', '3', '4', '1', '2'])
# (u'ON commence \xe0 fe tranquilifer \xe0 Varfovie, depuis les lettres', '1713-10-09', ['1', '2', '3', '4', '1', '2'])
# ("LEs Lettres de Rome du 22 Avril dirent, que Mardt marin, avakt'qu'on clebrat la Meffe, it", '1713-05-12', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-05-13', ['1', '2'])
# ('Husum den II Mey. De Graf Steepbock heeft gifteren by den', '1713-05-16', ['1', '2', '3', '4', '5', '6'])
# (u'LEs Lettres de Madrit du 25 Avril marquent, que- Don I ernando Suare\xef dc Figueroa, Mar\xe9-', '1713-05-16', ['1', '2', '1', '2'])
# ('NEDERLANDEN.', '1713-05-23', ['1', '2', '3', '4'])
# (u"Il y a des Lettres de Cadix du 23 Avril dernter qutpoertent, qu'on y \xe9rbittbujours fort en peine", '1713-05-23', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-05-06', ['1', '2'])
# ('SUPLEMENT', '1713-05-29', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-05-08', ['1', '2', '3', '4'])
# ('SUPPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS.', '1713-05-26', ['1', '2', '3', '4', '1', '2'])
# ('De la Haie le 21. Mai.', '1713-05-18', ['1', '2', '3', '4', '1', '2', '3', '4'])
# ('Advertentie', '1713-05-18', ['1', '2'])
# ('SUPPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS.', '1713-05-30', ['1', '2', '3', '4', '1', '2'])
# ('Roma den 18 Mey. De Cardinact Aquaviva 16 door Coning Phi-', '1713-05-30', ['1', '2', '3', '4'])
# (u"Suivant les de Milan, l'lmp\xe9ratrice devoit partie", '1713-05-11', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-05-11', ['1', '2'])
# ('SUPLEMENT', '1713-05-15', ['1', '2', '3', '4', '1', '2'])
# ('Parijs den 22 Mey. Dier zijn geen tydingen direct van', '1713-05-27', ['1', '2', '3', '4'])
# (u"LEs lettres de Milan du 22. Avril difent, que le d\xe9part de l'Imp\xe9racrice", '1713-05-04', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-05-04', ['1', '2'])
# ('LEs Lettres de Naples du 25 Avril dernier portent, que le Comte Charles Borromce qui en eft', '1713-05-19', ['1', '2', '3', '4', '1', '2'])
# (u"LEs Lettres de Madrit du 11 ajoutent \xe0 cequi en a \xe9t\xe9 dit dans n\xf4tre Gazette d'aujourd'hui a", '1713-05-02', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-05-02', ['1', '2'])
# (u"Ily a un grand mouvement de troupes en Allemagne, & l'on \xe9crit dc Francfort.", '1713-05-01', ['1', '2', '3', '4', '1', '2'])
# ('SUPLEMENT', '1713-05-25', ['1', '2', '3', '4', '1', '2'])
# ('NEDERLANDEN.', '1713-05-25', ['1', '2', '3', '4'])
# ('Advertentie', '1713-05-20', ['1', '2'])
# ('MESSIEURS.', '1713-05-05', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-05-09', ['1', '2'])
# (u"LEs Lettres de Varfovie du 15 ajoutent \xe0ce que nous avons deja dit dans notre Gazette , qu'en-", '1713-05-09', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-09-12', ['1', '2'])
# (u'L Es Lettres de Madrit du 11 du Mois dernier ajoutent a ce qui en a \xe9;c dit dans n\xf4tre Gazette', '1713-09-12', ['1', '2', '3', '4', '1', '2'])
# ('Madrid den 28 Auguitt. Men legdar decommg feerele ondre aen', '1713-09-16', ['1', '2', '3', '4'])
# ('Lifhbou den 16 Aug. .Met eenCopy van een Brief van St.Hubees', '1713-09-23', ['1', '2', '3', '4'])
# ('Advertentie', '1713-09-28', ['1', '2'])
# (u'\u25a0 f EsLcttrcsdcNap.es du 15 du Mois dernier portent, .que le Viccroy s apliquoit tou.ours ao*', '1713-09-08', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-09-26', ['1', '2'])
# ('Advertentie', '1713-09-26', ['1', '2', '3', '4', '1', '2'])
# ("ON ne doute pins que la crainte qu'on avoit en Pologne d'une ir-", '1713-09-18', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-09-30', ['1', '2'])
# (u'PAr les lettres de Gernsheim du i_. on aprend, que depuis le d\xe9-', '1713-09-21', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-09-21', ['1', '2'])
# ('Advertentie', '1713-09-07', ['1', '2'])
# (u'N Os M\xe9moires de Rome du 16 du Mois dernier ajoutent \xe0 ce qbi en g \xe9t\xe9 dit dans n\xf4tre', '1713-09-15', ['1', '2', '3', '4', '1', '2'])
# ('NEDERLANDEN.', '1713-09-19', ['1', '2', '3', '4'])
# (u'i "f Ous iprenons de Cadix du zo du Mois dernier, qu\'on \xe9toit encore dans I incertitude ,', '1713-09-19', ['1', '2', '3', '4', '1', '2'])
# (u"I J^v zecrc d'Aujourd'hui, que le Dimanche pr\xe9c\xe8dent la Place A'jvohc avoit \xe9;\xe9 inond\xe9e , com-", '1713-09-01', ['1', '2', '3', '4', '1', '2'])
# (u'LEs aVis du Camp Imp\xe9rial pr\xe8s de Muhlberg du iS. confirment que.', '1713-09-25', ['1', '2', '3', '4', '1', '2'])
# ('NEDERLANDEN.', '1713-09-05', ['1', '2', '3', '4'])
# ('Lts Lettres tic Madrit du 15 du Mois dernier ajoutent ace que nous en avons dit ailleurs , que', '1713-09-05', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-09-22', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1713-09-09', ['1', '2'])
# ('Advertentie', '1719-12-12', ['1', '2'])
# ('Advertentie', '1719-12-16', ['1', '2'])
# ('Advertentie', '1719-12-23', ['1', '2'])
# ('Advertentie', '1719-12-28', ['1', '2'])
# ('Advertentie', '1719-12-26', ['1', '2'])
# ('Advertentie', '1719-12-30', ['1', '2'])
# ('Advertentie', '1719-12-21', ['1', '2'])
# ('Advertentie', '1719-12-07', ['1', '2'])
# ('Advertentie', '1719-12-14', ['1', '2'])
# ('Advertentie', '1719-12-19', ['1', '2'])
# ('Advertentie', '1719-12-02', ['1', '2'])
# (u'Napels dm 7 November. Na d\u2019overgacf van de Citadel vaa', '1719-12-05', ['1', '2', '1', '2'])
# ('Advertentie', '1719-12-09', ['1', '2'])
# ('Advertentie', '1719-06-13', ['1', '2'])
# ('Advertentie', '1719-06-06', ['1', '2'])
# ('Advertentie', '1719-06-06', ['1', '2'])
# ('Advertentie', '1719-06-24', ['1', '2'])
# ('Advertentie', '1719-06-29', ['1', '2'])
# ('Advertentie', '1719-06-29', ['1', '2'])
# ('Advertentie', '1719-06-08', ['1', '2'])
# ('Advertentie', '1719-06-15', ['1', '2'])
# ('Advertentie', '1719-06-17', ['1', '2'])
# ('Advertentie', '1719-06-17', ['1', '2'])
# ('Advertentie', '1719-06-27', ['1', '2'])
# ('Advertentie', '1719-06-27', ['1', '2'])
# ('Advertentie', '1719-06-03', ['1', '2'])
# ('Advertentie', '1719-06-01', ['1', '2'])
# ('Advertentie', '1719-06-10', ['1', '2'])
# ('Advertentie', '1719-06-20', ['1', '2'])
# ('Advertentie', '1719-06-22', ['1', '2'])
# ('Advertentie', '1719-08-12', ['1', '2'])
# ('Advertentie', '1719-08-31', ['1', '2'])
# ('Advertentie', '1719-08-24', ['1', '2'])
# ('Advertentie', '1719-08-29', ['1', '2'])
# ('Advertentie', '1719-08-08', ['1', '2'])
# ('Advertentie', '1719-08-26', ['1', '2'])
# ('Advertentie', '1719-08-15', ['1', '2'])
# ('Advertentie', '1719-08-17', ['1', '2'])
# ('Advertentie', '1719-08-03', ['1', '2'])
# ('Advertentie', '1719-08-03', ['1', '2'])
# ('Advertentie', '1719-08-19', ['1', '2'])
# ('NEDERLANDEN.', '1719-08-01', ['1', '2', '1', '2'])
# ('Advertentie', '1719-08-10', ['1', '2'])
# ('Advertentie', '1719-08-05', ['1', '2'])
# ('Advertentie', '1719-08-22', ['1', '2'])
# ('Advertentie', '1719-07-13', ['1', '2'])
# ('Advertentie', '1719-07-06', ['1', '2'])
# ('Advertentie', '1719-07-29', ['1', '2'])
# ('Advertentie', '1719-07-08', ['1', '2'])
# ('Advertentie', '1719-07-18', ['1', '2'])
# ('Advertentie', '1719-07-11', ['1', '2'])
# ('Advertentie', '1719-07-15', ['1', '2'])
# ('Napels den 4 July. Sondag arriveerde onfe nieuwe Vieeroy Grect', '1719-07-27', ['1', '2', '1', '2'])
# ('Advertentie', '1719-07-04', ['1', '2'])
# (u'Duytslant en d\u2019aengrensende Rijcken.', '1719-07-01', ['1'])
# ('Advertentie', '1719-07-01', ['1', '2'])
# ('Advertentie', '1719-07-25', ['1', '2'])
# ('Advertentie', '1719-07-20', ['1', '2'])
# ('Advertentie', '1719-07-22', ['1', '2'])
# ('Napeis den 24 o&ober/ Op dit moment arriveert een Exprene', '1719-11-16', ['1', '2', '1', '2'])
# ('Advertentie', '1719-11-23', ['1', '2'])
# ('Advertentie', '1719-11-28', ['1', '2'])
# ('Advertentie', '1719-11-18', ['1', '2'])
# ('Advertentie', '1719-11-30', ['1', '2'])
# ('Advertentie', '1719-11-21', ['1', '2'])
# ('Advertentie', '1719-11-07', ['1', '2'])
# ('Advertentie', '1719-11-11', ['1', '2'])
# ('Advertentie', '1719-11-14', ['1', '2'])
# ('Advertentie', '1719-11-04', ['1', '2'])
# ('Advertentie', '1719-11-02', ['1', '2'])
# ('Advertentie', '1719-11-25', ['1', '2'])
# ('Advertentie', '1719-11-09', ['1', '2'])
# ('Advertentie', '1719-03-16', ['1', '2'])
# ('Advertentie', '1719-03-23', ['1', '2'])
# ('Advertentie', '1719-03-28', ['1', '2'])
# ('Advertentie', '1719-03-28', ['1', '2'])
# ('Advertentie', '1719-03-18', ['1', '2'])
# ('Advertentie', '1719-03-30', ['1', '2'])
# ('Advertentie', '1719-03-30', ['1', '2'])
# ('Advertentie', '1719-03-21', ['1', '2'])
# ('Advertentie', '1719-03-07', ['1', '2'])
# ('Advertentie', '1719-03-11', ['1', '2'])
# ('Advertentie', '1719-03-14', ['1', '2'])
# ('Advertentie', '1719-03-04', ['1', '2'])
# ('Advertentie', '1719-03-02', ['1', '2'])
# ('Advertentie', '1719-03-25', ['1', '2'])
# ('Advertentie', '1719-03-09', ['1', '2'])
# ('Advertentie', '1719-04-13', ['1', '2'])
# ('Advertentie', '1719-04-06', ['1', '2'])
# ('Advertentie', '1719-04-29', ['1', '2'])
# ('Advertentie', '1719-04-08', ['1', '2'])
# ('Advertentie', '1719-04-18', ['1', '2'])
# ('Advertentie', '1719-04-18', ['1', '2'])
# ('Advertentie', '1719-04-11', ['1', '2'])
# ('Advertentie', '1719-04-15', ['1', '2'])
# ('Advertentie', '1719-04-27', ['1', '2'])
# ('Advertentie', '1719-04-04', ['1', '2'])
# ('Advertentie', '1719-04-01', ['1', '2'])
# ('Advertentie', '1719-04-25', ['1', '2'])
# ('Advertentie', '1719-04-20', ['1', '2'])
# ('Advertentie', '1719-04-20', ['1', '2'])
# ('Advertentie', '1719-04-22', ['1', '2'])
# ('Advertentie', '1719-02-16', ['1', '2'])
# ('Advertentie', '1719-02-23', ['1', '2'])
# ('Advertentie', '1719-02-28', ['1', '2'])
# ('Advertentie', '1719-02-18', ['1', '2'])
# ('Advertentie', '1719-02-21', ['1', '2'])
# ('Advertentie', '1719-02-07', ['1', '2'])
# ('Advertentie', '1719-02-11', ['1', '2'])
# ('Advertentie', '1719-02-14', ['1', '2'])
# ('Advertentie', '1719-02-04', ['1', '2'])
# ('Advertentie', '1719-02-02', ['1', '2'])
# ('Advertentie', '1719-02-25', ['1', '2'])
# ('Advertentie', '1719-02-09', ['1', '2'])
# ('Advertentie', '1719-01-12', ['1', '2'])
# ('Advertentie', '1719-01-31', ['1', '2'])
# ('Advertentie', '1719-01-28', ['1', '2'])
# ('Advertentie', '1719-01-24', ['1', '2'])
# ('Advertentie', '1719-01-26', ['1', '2'])
# ('Lflabon den 2c December. De Schepen van de Bahia, na Port', '1719-01-21', ['1', '2', '1', '2'])
# ('Advertentie', '1719-01-07', ['1', '2'])
# ('NEDERLANDEN.', '1719-01-17', ['1', '2', '1', '2'])
# ('Advertentie', '1719-01-14', ['1', '2'])
# ('Advertentie', '1719-01-14', ['1', '2'])
# ('Advertentie', '1719-01-03', ['1', '2'])
# ('Advertentie', '1719-01-19', ['1', '2'])
# ('Advertentie', '1719-01-10', ['1', '2'])
# ('Advertentie', '1719-01-05', ['1', '2'])
# ('NEDERLANDEN.', '1719-10-12', ['1', '2', '1', '2'])
# ('Advertentie', '1719-10-31', ['1', '2'])
# ('Advertentie', '1719-10-31', ['1', '2'])
# ('Advertentie', '1719-10-28', ['1', '2'])
# ('Advertentie', '1719-10-24', ['1', '2'])
# ('Advertentie', '1719-10-26', ['1', '2'])
# ('Advertentie', '1719-10-21', ['1', '2'])
# ('Advertentie', '1719-10-07', ['1', '2'])
# ('Advertentie', '1719-10-07', ['1', '2'])
# ('Advertentie', '1719-10-17', ['1', '2'])
# ('Advertentie', '1719-10-14', ['1', '2'])
# ('Advertentie', '1719-10-03', ['1', '2'])
# ('Advertentie', '1719-10-19', ['1', '2'])
# ('Advertentie', '1719-10-10', ['1', '2'])
# ('Advertentie', '1719-10-05', ['1', '2'])
# ('Advertentie', '1719-05-13', ['1', '2'])
# ('Advertentie', '1719-05-16', ['1', '2'])
# ('Advertentie', '1719-05-23', ['1', '2'])
# ('Advertentie', '1719-05-06', ['1', '2'])
# ('Advertentie', '1719-05-18', ['1', '2'])
# ('Advertentie', '1719-05-30', ['1', '2'])
# ('Advertentie', '1719-05-11', ['1', '2'])
# ('Advertentie', '1719-05-27', ['1', '2'])
# ('Advertentie', '1719-05-04', ['1', '2'])
# ('Advertentie', '1719-05-02', ['1', '2'])
# ('Advertentie', '1719-05-25', ['1', '2'])
# ('Advertentie', '1719-05-20', ['1', '2'])
# ('Advertentie', '1719-05-09', ['1', '2'])
# ('Advertentie', '1719-09-12', ['1', '2'])
# ('Advertentie', '1719-09-16', ['1', '2'])
# ('Advertentie', '1719-09-23', ['1', '2'])
# ('Advertentie', '1719-09-28', ['1', '2'])
# ('Advertentie', '1719-09-26', ['1', '2'])
# ('Advertentie', '1719-09-30', ['1', '2'])
# ('Advertentie', '1719-09-21', ['1', '2'])
# ('Advertentie', '1719-09-07', ['1', '2'])
# ('Advertentie', '1719-09-14', ['1', '2'])
# ('Advertentie', '1719-09-19', ['1', '2'])
# ('Advertentie', '1719-09-02', ['1', '2'])
# ('Advertentie', '1719-09-05', ['1', '2'])
# ('Advertentie', '1719-09-09', ['1', '2'])
# ('Advertentie', '1717-12-16', ['1', '2'])
# ('Advertentie', '1717-12-23', ['1', '2'])
# ('Advertentie', '1717-12-28', ['1', '2'])
# ('Advertentie', '1717-12-18', ['1', '2'])
# ('Advertentie', '1717-12-30', ['1', '2'])
# ('Advertentie', '1717-12-21', ['1', '2'])
# ('Advertentie', '1717-12-07', ['1', '2'])
# ('Advertentie', '1717-12-11', ['1', '2'])
# ('Advertentie', '1717-12-14', ['1', '2'])
# ('Advertentie', '1717-12-04', ['1', '2'])
# ('Advertentie', '1717-12-02', ['1', '2'])
# ('Advertentie', '1717-12-25', ['1', '2'])
# ('Advertentie', '1717-12-09', ['1', '2'])
# ('Advertentie', '1717-06-12', ['1', '2'])
# ('Advertentie', '1717-06-24', ['1', '2'])
# ('Advertentie', '1717-06-29', ['1', '2'])
# ('Advertentie', '1717-06-08', ['1', '2'])
# ('Advertentie', '1717-06-26', ['1', '2'])
# ('Advertentie', '1717-06-26', ['1', '2'])
# ('Advertentie', '1717-06-15', ['1', '2'])
# ('Advertentie', '1717-06-15', ['1', '2'])
# ('Advertentie', '1717-06-17', ['1', '2'])
# ('Advertentie', '1717-06-17', ['1', '2'])
# ('Advertentie', '1717-06-03', ['1', '2'])
# ('Advertentie', '1717-06-19', ['1', '2'])
# ('Advertentie', '1717-06-01', ['1', '2'])
# ('Advertentie', '1717-06-01', ['1', '2'])
# ('Advertentie', '1717-06-10', ['1', '2'])
# ('Advertentie', '1717-06-05', ['1', '2'])
# ('Advertentie', '1717-06-22', ['1', '2'])
# ('Advertentie', '1717-08-12', ['1', '2'])
# ('Advertentie', '1717-08-31', ['1', '2'])
# ('Advertentie', '1717-08-28', ['1', '2'])
# ('Advertentie', '1717-08-24', ['1', '2'])
# ('Advertentie', '1717-08-26', ['1', '2'])
# ('Advertentie', '1717-08-21', ['1', '2'])
# ('Advertentie', '1717-08-07', ['1', '2'])
# ('Advertentie', '1717-08-07', ['1', '2'])
# ('Advertentie', '1717-08-17', ['1', '2'])
# ('Advertentie', '1717-08-14', ['1', '2'])
# ('Advertentie', '1717-08-03', ['1', '2'])
# ('Advertentie', '1717-08-19', ['1', '2'])
# ('Advertentie', '1717-08-10', ['1', '2'])
# ('Advertentie', '1717-08-05', ['1', '2'])
# ('Advertentie', '1717-08-05', ['1', '2'])
# ('Advertentie', '1717-07-13', ['1', '2'])
# ('Advertentie', '1717-07-31', ['1', '2'])
# ('Advertentie', '1717-07-16', ['1', '2'])
# ('Advertentie', '1717-07-06', ['1', '2'])
# ('Advertentie', '1717-07-24', ['1', '2'])
# ('Advertentie', '1717-07-29', ['1', '2'])
# ('Advertentie', '1717-07-08', ['1', '2'])
# ('Advertentie', '1717-07-15', ['1', '2'])
# ('Advertentie', '1717-07-17', ['1', '2'])
# ('Advertentie', '1717-07-27', ['1', '2'])
# ('Advertentie', '1717-07-27', ['1', '2'])
# ('Advertentie', '1717-07-03', ['1', '2'])
# ('Advertentie', '1717-07-03', ['1', '2'])
# ('Advertentie', '1717-07-01', ['1', '2'])
# ('Advertentie', '1717-07-01', ['1', '2'])
# ('Advertentie', '1717-07-10', ['1', '2'])
# ('Advertentie', '1717-07-20', ['1', '2'])
# ('Advertentie', '1717-07-20', ['1', '2'])
# ('Advertentie', '1717-07-22', ['1', '2'])
# ('Advertentie', '1717-07-22', ['1', '2'])
# ('Advertentie', '1717-11-13', ['1', '2'])
# ('Advertentie', '1717-11-16', ['1', '2'])
# ('Advertentie', '1717-11-23', ['1', '2'])
# ('Advertentie', '1717-11-06', ['1', '2'])
# ('Advertentie', '1717-11-18', ['1', '2'])
# ('Advertentie', '1717-11-30', ['1', '2'])
# ('Advertentie', '1717-11-11', ['1', '2'])
# ('Advertentie', '1717-11-27', ['1', '2'])
# ('Advertentie', '1717-11-04', ['1', '2'])
# ('Advertentie', '1717-11-02', ['1', '2'])
# ('Advertentie', '1717-11-25', ['1', '2'])
# ('Advertentie', '1717-11-20', ['1', '2'])
# ('Advertentie', '1717-11-09', ['1', '2'])
# ('Advertentie', '1717-03-13', ['1', '2'])
# ('Advertentie', '1717-03-13', ['1', '2'])
# ('Advertentie', '1717-03-16', ['1', '2'])
# ('Advertentie', '1717-03-23', ['1', '2'])
# ('Advertentie', '1717-03-23', ['1', '2'])
# ('Advertentie', '1717-03-06', ['1', '2'])
# ('Advertentie', '1717-03-18', ['1', '2'])
# ('Advertentie', '1717-03-30', ['1', '2'])
# ('Advertentie', '1717-03-27', ['1', '2'])
# ('Advertentie', '1717-03-04', ['1', '2'])
# ('Advertentie', '1717-03-02', ['1', '2'])
# ('Advertentie', '1717-03-25', ['1', '2'])
# ('Advertentie', '1717-03-20', ['1', '2'])
# ('Advertentie', '1717-03-09', ['1', '2'])
# ('Advertentie', '1717-03-09', ['1', '2'])
# ('Advertentie', '1717-04-13', ['1', '2'])
# ('Advertentie', '1717-04-06', ['1', '2'])
# ('Advertentie', '1717-04-06', ['1', '2'])
# ('Advertentie', '1717-04-24', ['1', '2'])
# ('Advertentie', '1717-04-24', ['1', '2'])
# ('Advertentie', '1717-04-29', ['1', '2'])
# ('Advertentie', '1717-04-08', ['1', '2'])
# ('Advertentie', '1717-04-15', ['1', '2'])
# ('Advertentie', '1717-04-17', ['1', '2'])
# ('Advertentie', '1717-04-27', ['1', '2'])
# ('Advertentie', '1717-04-03', ['1', '2'])
# ('Advertentie', '1717-04-03', ['1', '2'])
# ('Advertentie', '1717-04-01', ['1', '2'])
# ('Advertentie', '1717-04-10', ['1', '2'])
# ('Advertentie', '1717-04-20', ['1', '2'])
# ('Advertentie', '1717-04-20', ['1', '2'])
# ('Advertentie', '1717-04-22', ['1', '2'])
# ('Advertentie', '1717-04-22', ['1', '2'])
# ('Advertentie', '1717-02-13', ['1', '2'])
# ('Advertentie', '1717-02-13', ['1', '2'])
# ('NEDERLANDEN.', '1717-02-16', ['1', '2', '3', '4'])
# ('Advertentie', '1717-02-23', ['1', '2'])
# ('Advertentie', '1717-02-23', ['1', '2'])
# ('Advertentie', '1717-02-06', ['1', '2'])
# ('Advertentie', '1717-02-18', ['1', '2'])
# ('Advertentie', '1717-02-11', ['1', '2'])
# ('Advertentie', '1717-02-27', ['1', '2'])
# ('Advertentie', '1717-02-04', ['1', '2'])
# ('Advertentie', '1717-02-04', ['1', '2'])
# ('Advertentie', '1717-02-02', ['1', '2'])
# ('Advertentie', '1717-02-02', ['1', '2'])
# ('Advertentie', '1717-02-25', ['1', '2'])
# ('Advertentie', '1717-02-20', ['1', '2'])
# ('Advertentie', '1717-02-09', ['1', '2'])
# ('Advertentie', '1717-01-12', ['1', '2'])
# ('Advertentie', '1717-01-16', ['1', '2'])
# ('Advertentie', '1717-01-23', ['1', '2'])
# ('Advertentie', '1717-01-23', ['1', '2'])
# ('Advertentie', '1717-01-28', ['1', '2'])
# ('Advertentie', '1717-01-26', ['1', '2'])
# ('Advertentie', '1717-01-30', ['1', '2'])
# ('Advertentie', '1717-01-30', ['1', '2'])
# ('Advertentie', '1717-01-21', ['1', '2'])
# ('Advertentie', '1717-01-21', ['1', '2'])
# ('Advertentie', '1717-01-07', ['1', '2'])
# ('Advertentie', '1717-01-14', ['1', '2'])
# ('Advertentie', '1717-01-14', ['1', '2'])
# ('Advertentie', '1717-01-19', ['1', '2'])
# ('Advertentie', '1717-01-02', ['1', '2'])
# ('Advertentie', '1717-01-05', ['1', '2'])
# ('Advertentie', '1717-01-09', ['1', '2'])
# ('Advertentie', '1717-10-12', ['1', '2'])
# ('Advertentie', '1717-10-16', ['1', '2'])
# ('Advertentie', '1717-10-16', ['1', '2'])
# ('Advertentie', '1717-10-23', ['1', '2'])
# ('Advertentie', '1717-10-28', ['1', '2'])
# ('Advertentie', '1717-10-26', ['1', '2'])
# ('Advertentie', '1717-10-30', ['1', '2'])
# ('Advertentie', '1717-10-21', ['1', '2'])
# ('Advertentie', '1717-10-07', ['1', '2'])
# ('Advertentie', '1717-10-14', ['1', '2'])
# ('Advertentie', '1717-10-14', ['1', '2'])
# ('Advertentie', '1717-10-19', ['1', '2'])
# ('Advertentie', '1717-10-02', ['1', '2'])
# ('Advertentie', '1717-10-05', ['1', '2'])
# ('Advertentie', '1717-10-09', ['1', '2'])
# ('Advertentie', '1717-05-13', ['1', '2'])
# ('Advertentie', '1717-05-13', ['1', '2'])
# ('Advertentie', '1717-05-06', ['1', '2'])
# ('NEDERLANDEN.', '1717-05-06', ['1', '2', '3', '4'])
# ('Advertentie', '1717-05-29', ['1', '2'])
# ('Advertentie', '1717-05-29', ['1', '2'])
# ('Advertentie', '1717-05-08', ['1', '2'])
# ('Advertentie', '1717-05-18', ['1', '2'])
# ('Advertentie', '1717-05-11', ['1', '2'])
# ('Advertentie', '1717-05-11', ['1', '2'])
# ('Advertentie', '1717-05-15', ['1', '2'])
# ('Advertentie', '1717-05-27', ['1', '2'])
# ('Advertentie', '1717-05-27', ['1', '2'])
# ('Advertentie', '1717-05-04', ['1', '2'])
# ('Advertentie', '1717-05-04', ['1', '2'])
# ('Advertentie', '1717-05-01', ['1', '2'])
# ('Advertentie', '1717-05-25', ['1', '2'])
# ('Advertentie', '1717-05-20', ['1', '2'])
# ('Advertentie', '1717-05-20', ['1', '2'])
# ('Advertentie', '1717-05-22', ['1', '2'])
# ('Advertentie', '1717-09-16', ['1', '2'])
# ('Advertentie', '1717-09-23', ['1', '2'])
# ('Advertentie', '1717-09-28', ['1', '2'])
# ('Advertentie', '1717-09-18', ['1', '2'])
# ('Advertentie', '1717-09-30', ['1', '2'])
# ('Advertentie', '1717-09-21', ['1', '2'])
# ('Advertentie', '1717-09-07', ['1', '2'])
# ('Advertentie', '1717-09-11', ['1', '2'])
# ('Advertentie', '1717-09-14', ['1', '2'])
# ('Advertentie', '1717-09-04', ['1', '2'])
# ('Advertentie', '1717-09-02', ['1', '2'])
# ('Advertentie', '1717-09-25', ['1', '2'])
# ('Advertentie', '1717-09-09', ['1', '2'])
# ('Advertentie', '1718-12-13', ['1', '2'])
# ('Advertentie', '1718-12-31', ['1', '2'])
# ('Advertentie', '1718-12-06', ['1', '2'])
# ('Advertentie', '1718-12-24', ['1', '2'])
# ('Advertentie', '1718-12-29', ['1', '2'])
# ('Advertentie', '1718-12-29', ['1', '2'])
# ('Advertentie', '1718-12-08', ['1', '2'])
# ('Advertentie', '1718-12-15', ['1', '2'])
# ('Advertentie', '1718-12-17', ['1', '2'])
# ('NEDERLANDEN.', '1718-12-27', ['1', '2', '3', '4'])
# ('Advertentie', '1718-12-03', ['1', '2'])
# ('Advertentie', '1718-12-01', ['1', '2'])
# ('Advertentie', '1718-12-10', ['1', '2'])
# ('Advertentie', '1718-12-20', ['1', '2'])
# ('Advertentie', '1718-12-22', ['1', '2'])
# ('Advertentie', '1718-06-16', ['1', '2'])
# ('Advertentie', '1718-06-23', ['1', '2'])
# ('Advertentie', '1718-06-28', ['1', '2'])
# ('Advertentie', '1718-06-18', ['1', '2'])
# ('Advertentie', '1718-06-30', ['1', '2'])
# ('Advertentie', '1718-06-21', ['1', '2'])
# ('Advertentie', '1718-06-07', ['1', '2'])
# ('Advertentie', '1718-06-11', ['1', '2'])
# ('Advertentie', '1718-06-14', ['1', '2'])
# ('Advertentie', '1718-06-04', ['1', '2'])
# ('Advertentie', '1718-06-02', ['1', '2'])
# ('Advertentie', '1718-06-25', ['1', '2'])
# ('Advertentie', '1718-06-09', ['1', '2'])
# ('Advertentie', '1718-08-13', ['1', '2'])
# ('Advertentie', '1718-08-16', ['1', '2'])
# ('Advertentie', '1718-08-23', ['1', '2'])
# ('Advertentie', '1718-08-06', ['1', '2'])
# ('Advertentie', '1718-08-18', ['1', '2'])
# ('Advertentie', '1718-08-30', ['1', '2'])
# ('Advertentie', '1718-08-11', ['1', '2'])
# ('Advertentie', '1718-08-27', ['1', '2'])
# ('Advertentie', '1718-08-04', ['1', '2'])
# ('Advertentie', '1718-08-02', ['1', '2'])
# ('Advertentie', '1718-08-25', ['1', '2'])
# ('Advertentie', '1718-08-20', ['1', '2'])
# ('Advertentie', '1718-08-09', ['1', '2'])
# ('Advertentie', '1718-07-12', ['1', '2'])
# ('Advertentie', '1718-07-16', ['1', '2'])
# ('Advertentie', '1718-07-23', ['1', '2'])
# ('Advertentie', '1718-07-28', ['1', '2'])
# ('Advertentie', '1718-07-26', ['1', '2'])
# ('Advertentie', '1718-07-30', ['1', '2'])
# ('Advertentie', '1718-07-21', ['1', '2'])
# ('Advertentie', '1718-07-07', ['1', '2'])
# ('Advertentie', '1718-07-14', ['1', '2'])
# ('Advertentie', '1718-07-19', ['1', '2'])
# ('Advertentie', '1718-07-02', ['1', '2'])
# ('Advertentie', '1718-07-05', ['1', '2'])
# ('Advertentie', '1718-07-09', ['1', '2'])
# ('Advertentie', '1718-11-12', ['1', '2'])
# ('Advertentie', '1718-11-24', ['1', '2'])
# ('Advertentie', '1718-11-29', ['1', '2'])
# ('Advertentie', '1718-11-08', ['1', '2'])
# ('Advertentie', '1718-11-26', ['1', '2'])
# ('Advertentie', '1718-11-15', ['1', '2'])
# ('Advertentie', '1718-11-17', ['1', '2'])
# ('Advertentie', '1718-11-03', ['1', '2'])
# ('Advertentie', '1718-11-19', ['1', '2'])
# ('Advertentie', '1718-11-01', ['1', '2'])
# ('Advertentie', '1718-11-10', ['1', '2'])
# ('Advertentie', '1718-11-05', ['1', '2'])
# ('Advertentie', '1718-11-22', ['1', '2'])
# ('Advertentie', '1718-03-12', ['1', '2'])
# ('Advertentie', '1718-03-31', ['1', '2'])
# ('Advertentie', '1718-03-24', ['1', '2'])
# ('Advertentie', '1718-03-29', ['1', '2'])
# ('Advertentie', '1718-03-08', ['1', '2'])
# ('Advertentie', '1718-03-26', ['1', '2'])
# ('Advertentie', '1718-03-26', ['1', '2'])
# ('Advertentie', '1718-03-15', ['1', '2'])
# ('Advertentie', '1718-03-17', ['1', '2'])
# ('Advertentie', '1718-03-03', ['1', '2'])
# ('Advertentie', '1718-03-19', ['1', '2'])
# ('Advertentie', '1718-03-19', ['1', '2'])
# ('Advertentie', '1718-03-01', ['1', '2'])
# ('Advertentie', '1718-03-01', ['1', '2'])
# ('Advertentie', '1718-03-10', ['1', '2'])
# ('Advertentie', '1718-03-05', ['1', '2'])
# ('Advertentie', '1718-03-22', ['1', '2'])
# ('Advertentie', '1718-04-12', ['1', '2'])
# ('Advertentie', '1718-04-16', ['1', '2'])
# ('Advertentie', '1718-04-23', ['1', '2'])
# ('Advertentie', '1718-04-28', ['1', '2'])
# ('Advertentie', '1718-04-28', ['1', '2'])
# ('Advertentie', '1718-04-26', ['1', '2'])
# ('Advertentie', '1718-04-30', ['1', '2'])
# ('Advertentie', '1718-04-21', ['1', '2'])
# ('Advertentie', '1718-04-07', ['1', '2'])
# ('Advertentie', '1718-04-14', ['1', '2'])
# ('Advertentie', '1718-04-19', ['1', '2'])
# ('Advertentie', '1718-04-02', ['1', '2'])
# ('Advertentie', '1718-04-05', ['1', '2'])
# ('Advertentie', '1718-04-09', ['1', '2'])
# ('Advertentie', '1718-02-12', ['1', '2'])
# ('Advertentie', '1718-02-24', ['1', '2'])
# ('Advertentie', '1718-02-08', ['1', '2'])
# ('Advertentie', '1718-02-26', ['1', '2'])
# ('Advertentie', '1718-02-15', ['1', '2'])
# ('Advertentie', '1718-02-17', ['1', '2'])
# ('Advertentie', '1718-02-03', ['1', '2'])
# ('Advertentie', '1718-02-19', ['1', '2'])
# ('Advertentie', '1718-02-01', ['1', '2'])
# ('Advertentie', '1718-02-10', ['1', '2'])
# ('Advertentie', '1718-02-05', ['1', '2'])
# ('Advertentie', '1718-02-22', ['1', '2'])
# ('Advertentie', '1718-02-22', ['1', '2'])
# ('Advertentie', '1718-01-13', ['1', '2'])
# ('Advertentie', '1718-01-06', ['1', '2'])
# ('Advertentie', '1718-01-29', ['1', '2'])
# ('Advertentie', '1718-01-08', ['1', '2'])
# ('Advertentie', '1718-01-18', ['1', '2'])
# ('Advertentie', '1718-01-11', ['1', '2'])
# ('Advertentie', '1718-01-15', ['1', '2'])
# ('Advertentie', '1718-01-04', ['1', '2'])
# ('Advertentie', '1718-01-01', ['1', '2'])
# ('Advertentie', '1718-01-25', ['1', '2'])
# ('Advertentie', '1718-01-25', ['1', '2'])
# ('Advertentie', '1718-01-20', ['1', '2'])
# ('Advertentie', '1718-01-20', ['1', '2'])
# ('Advertentie', '1718-01-22', ['1', '2'])
# ('Advertentie', '1718-10-13', ['1', '2'])
# ('Advertentie', '1718-10-06', ['1', '2'])
# ('Advertentie', '1718-10-06', ['1', '2'])
# ('Advertentie', '1718-10-29', ['1', '2'])
# ('Advertentie', '1718-10-08', ['1', '2'])
# ('Advertentie', '1718-10-18', ['1', '2'])
# ('Advertentie', '1718-10-11', ['1', '2'])
# ('Advertentie', '1718-10-15', ['1', '2'])
# ('Advertentie', '1718-10-27', ['1', '2'])
# ('Advertentie', '1718-10-04', ['1', '2'])
# ('Advertentie', '1718-10-01', ['1', '2'])
# ('Advertentie', '1718-10-25', ['1', '2'])
# ('Advertentie', '1718-10-20', ['1', '2'])
# ('Advertentie', '1718-10-22', ['1', '2'])
# ('Advertentie', '1718-05-12', ['1', '2'])
# ('Advertentie', '1718-05-31', ['1', '2'])
# ('Advertentie', '1718-05-28', ['1', '2'])
# ('Advertentie', '1718-05-24', ['1', '2'])
# ('Advertentie', '1718-05-26', ['1', '2'])
# ('Advertentie', '1718-05-21', ['1', '2'])
# ('Advertentie', '1718-05-07', ['1', '2'])
# ('Advertentie', '1718-05-07', ['1', '2'])
# ('Advertentie', '1718-05-17', ['1', '2'])
# ('Advertentie', '1718-05-14', ['1', '2'])
# ('Advertentie', '1718-05-03', ['1', '2'])
# ('Advertentie', '1718-05-19', ['1', '2'])
# ('Advertentie', '1718-05-10', ['1', '2'])
# ('Advertentie', '1718-05-05', ['1', '2'])
# ('Advertentie', '1718-09-13', ['1', '2'])
# ('Advertentie', '1718-09-06', ['1', '2'])
# ('Advertentie', '1718-09-24', ['1', '2'])
# ('Advertentie', '1718-09-29', ['1', '2'])
# ('Advertentie', '1718-09-08', ['1', '2'])
# ('Advertentie', '1718-09-15', ['1', '2'])
# ('Advertentie', '1718-09-17', ['1', '2'])
# ('Advertentie', '1718-09-27', ['1', '2'])
# ('Advertentie', '1718-09-27', ['1', '2'])
# ('Advertentie', '1718-09-03', ['1', '2'])
# ('Advertentie', '1718-09-01', ['1', '2'])
# ('Advertentie', '1718-09-10', ['1', '2'])
# ('Advertentie', '1718-09-20', ['1', '2'])
# ('Advertentie', '1718-09-22', ['1', '2'])
# (u'A la Gazette de Rotterdam, du 13. D\xe9cembre 1714.', '1714-12-13', ['1', '2', '3', '4', '1', '2'])
# ('NEDERLANDEN.', '1714-12-13', ['1', '2', '3', '4'])
# (u'A la Gazette de Rotterdam, du 6. D\xe9cembre 1714.', '1714-12-06', ['1', '2', '3', '4', '1', '2'])
# ('NEDERLANDEN.', '1714-12-06', ['1', '2', '3', '4'])
# ('Advertentie', '1714-12-28', ['1', '2', '3', '4', '1', '2'])
# (u'ON commence \xe0 ajouter foi aux bruits qui ont courn depuis si', '1714-12-24', ['1', '2', '3', '4', '1'])
# ('Advertentie', '1714-12-29', ['1', '2'])
# ('Advertentie', '1714-12-08', ['1', '2'])
# ('SUPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS. De LEIDE le 18 Decembre 1714.', '1714-12-18', ['1', '2', '3', '4', '1', '2'])
# ('Advertentie', '1714-12-18', ['1', '2'])
# ('UPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS. De LEIDE le 21 Decembre 1714.', '1714-12-21', ['1', '2', '3', '4', '1', '2'])
# ('TES Letres do Rome du 17 Novembre dernier aioutcnt acec-ue nous en avons dit ailleurs', '1714-12-07', ['1', '2', '3', '4', '1', '2'])
# ("L Es Letres de Varfovie dj 14 du Mois dernier portent, qu'on croyoit que le raport cjue le Pai", '1714-12-11', ['1', '2', '3', '4', '1', '2'])
# ...
# ('Advertentie', '1715-05-18', ['1', '2'])
# ('Advertentie', '1715-05-30', ['1', '2'])
# ('NEDERLANDEN.', '1715-05-21', ['1', '2', '3', '4'])
# ('SUPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS. De LEIDE le 7 May 1715.', '1715-05-07', ['1', '2', '3', '4', '1', '2'])
# ('NEDERLANDEN.', '1715-05-07', ['1', '2', '3', '4'])
# ('Advertentie', '1715-05-11', ['1', '2'])
# ('Advertentie', '1715-05-14', ['1', '2'])
# ('SUPLEMENT AUX NOUVELLES EXTRAORDINAIRES DE DIVERS ENDROITS. De LEIDE le 3 May 1715.', '1715-05-03', ['1', '2', '3', '4', '1', '2'])
# (u'Duytflant en d\u2019aengrenfende Rijcken.', '1715-05-04', ['1', '2', '3', '4'])
# ('Napels den 9 April. De Keyfer beeft een grote fomma Gelds ver-', '1715-05-02', ['1', '2', '3', '4'])
# ('Advertentie', '1715-05-25', ['1', '2'])
# ('SUPLEMENT AUX NOUVEILES EXTRAOR DE DIVERS EN DROITS.', '1715-05-10', ['1', '2', '3', '4', '1', '2', '1'])
# ('Advertentie', '1715-05-09', ['1', '2'])
# (u'Roma den 24 Augufti. De Paul heeft fijn ongemack We\u2019er op', '1715-09-12', ['1', '2', '3', '4'])
# ('LiflTibon den 17 Augufti, Hier lijn gearriveert de Schepen We', '1715-09-28', ['1', '2', '3', '4'])
# ('Advertentie', '1715-09-24', ['1', '2'])
# (u'Roma den 7 September. De Paus bevint fig we\u2019er met fijn oude', '1715-09-26', ['1', '2', '3', '4'])
# ('Advertentie', '1715-09-21', ['1', '2'])
# ('NEDERLANDEN.', '1715-09-07', ['1', '2', '3', '4'])
# ('Advertentie', '1715-09-17', ['1', '2'])
# ('Advertentie', '1715-09-14', ['1', '2'])
# ('NEDERLANDEN.', '1715-09-03', ['1', '2', '3', '4'])
# ('Advertentie', '1715-09-19', ['1', '2'])
# ('NEDERLANDEN.', '1715-09-10', ['1', '2', '3', '4'])
# ('Roma den 17 Augufti. De Paus gaf. Woensdag Audientie aen', '1715-09-05', ['1', '2', '3', '4'])
# ('Advertentie', '1711-12-12', ['1', '2'])
# ('Advertentie', '1711-12-31', ['1', '2'])
# ('Advertentie', '1711-12-16', ['1', '2'])
# ('Advertentie', '1711-12-23', ['1', '2'])
# ('Advertentie', '1711-12-28', ['1', '2'])
# ('Advertentie', '1711-12-24', ['1', '2'])
# ('Advertentie', '1711-12-29', ['1', '2'])
# ('Advertentie', '1711-12-08', ['1', '2'])
# ('Advertentie', '1711-12-26', ['1', '2'])
# ('Advertentie', '1711-12-30', ['1', '2'])
# ('Advertentie', '1711-12-21', ['1', '2'])
# ('Advertentie', '1711-12-11', ['1', '2'])
# ('Advertentie', '1711-12-15', ['1', '2'])
# ('Advertentie', '1711-12-15', ['1', '2'])
# ('Advertentie', '1711-12-17', ['1', '2'])
# ('Advertentie', '1711-12-17', ['1', '2'])
# ('Advertentie', '1711-12-14', ['1', '2'])
# ('Advertentie', '1711-12-03', ['1', '2'])
# ('Advertentie', '1711-12-04', ['1', '2'])
# ('Advertentie', '1711-12-19', ['1', '2'])
# ('Advertentie', '1711-12-02', ['1', '2'])
# ('Advertentie', '1711-12-01', ['1', '2'])
# ('Advertentie', '1711-12-25', ['1', '2'])
# ('Advertentie', '1711-12-05', ['1', '2'])
# ('Advertentie', '1711-12-22', ['1', '2'])
# ('Advertentie', '1711-12-09', ['1', '2'])
# ('Advertentie', '1711-06-12', ['1', '2'])
# ('Advertentie', '1711-06-13', ['1', '2'])
# ('Advertentie', '1711-06-13', ['1', '2'])
# ('Advertentie', '1711-06-16', ['1', '2'])
# ('Advertentie', '1711-06-23', ['1', '2'])
# ('Advertentie', '1711-06-06', ['1', '2'])
# ('Advertentie', '1711-06-24', ['1', '2'])
# ('Advertentie', '1711-06-29', ['1', '2'])
# ('Advertentie', '1711-06-08', ['1', '2'])
# ('Advertentie', '1711-06-26', ['1', '2'])
# ('Advertentie', '1711-06-18', ['1', '2'])
# ('Advertentie', '1711-06-30', ['1', '2'])
# ('Advertentie', '1711-06-30', ['1', '2'])
# ('Advertentie', '1711-06-11', ['1', '2'])
# ('Advertentie', '1711-06-15', ['1', '2'])
# ('Advertentie', '1711-06-17', ['1', '2'])
# ('Advertentie', '1711-06-27', ['1', '2'])
# ('Advertentie', '1711-06-27', ['1', '2'])
# ('Advertentie', '1711-06-03', ['1', '2'])
# ('Advertentie', '1711-06-04', ['1', '2'])
# ('Advertentie', '1711-06-19', ['1', '2'])
# ('Advertentie', '1711-06-02', ['1', '2'])
# ('Advertentie', '1711-06-01', ['1', '2'])
# ('Advertentie', '1711-06-25', ['1', '2'])
# ('Advertentie', '1711-06-25', ['1', '2'])
# ('Advertentie', '1711-06-10', ['1', '2'])
# ('Advertentie', '1711-06-20', ['1', '2'])
# ('Advertentie', '1711-06-20', ['1', '2'])
# ('Advertentie', '1711-06-05', ['1', '2'])
# ('Advertentie', '1711-06-22', ['1', '2'])
# ('Advertentie', '1711-06-09', ['1', '2'])
# ('Advertentie', '1711-08-12', ['1', '2'])
# ('Advertentie', '1711-08-13', ['1', '2'])
# ('Advertentie', '1711-08-13', ['1', '2'])
# ('Advertentie', '1711-08-31', ['1', '2'])
# ('Advertentie', '1711-08-06', ['1', '2'])
# ('Advertentie', '1711-08-28', ['1', '2'])
# ('Advertentie', '1711-08-24', ['1', '2'])
# ('Advertentie', '1711-08-29', ['1', '2'])
# ('Advertentie', '1711-08-08', ['1', '2'])
# ('Advertentie', '1711-08-26', ['1', '2'])
# ('Advertentie', '1711-08-18', ['1', '2'])
# ('Advertentie', '1711-08-21', ['1', '2'])
# ('Advertentie', '1711-08-07', ['1', '2'])
# ('Advertentie', '1711-08-11', ['1', '2'])
# ('Advertentie', '1711-08-11', ['1', '2'])
# ('Advertentie', '1711-08-15', ['1', '2'])
# ('Advertentie', '1711-08-15', ['1', '2'])
# ('Advertentie', '1711-08-17', ['1', '2'])
# ('Advertentie', '1711-08-14', ['1', '2'])
# ('Advertentie', '1711-08-27', ['1', '2'])
# ('Advertentie', '1711-08-04', ['1', '2'])
# ('Advertentie', '1711-08-19', ['1', '2'])
# ('Advertentie', '1711-08-01', ['1', '2'])
# ('Advertentie', '1711-08-25', ['1', '2'])
# ('Advertentie', '1711-08-25', ['1', '2'])
# ('Advertentie', '1711-08-10', ['1', '2'])
# ('Advertentie', '1711-08-20', ['1', '2'])
# ('Advertentie', '1711-08-05', ['1', '2'])
# ('Advertentie', '1711-08-22', ['1', '2'])
# ('Advertentie', '1711-08-22', ['1', '2'])
# ('Advertentie', '1711-07-13', ['1', '2'])
# ('Advertentie', '1711-07-31', ['1', '2'])
# ('Advertentie', '1711-07-16', ['1', '2'])
# (u'Roma den 4 July. Sondig reveneerde dc Pau\xbb van Cafllei Gandol.', '1711-07-23', ['1', '2', '3', '4'])
# ('Advertentie', '1711-07-06', ['1', '2'])
# ('Advertentie', '1711-07-28', ['1', '2'])
# ('Advertentie', '1711-07-24', ['1', '2'])
# ('Advertentie', '1711-07-29', ['1', '2'])
# ('Advertentie', '1711-07-08', ['1', '2'])
# ('Advertentie', '1711-07-18', ['1', '2'])
# ('Advertentie', '1711-07-30', ['1', '2'])
# ('Advertentie', '1711-07-30', ['1', '2'])
# ('Advertentie', '1711-07-21', ['1', '2'])
# ('Advertentie', '1711-07-21', ['1', '2'])
# ('Advertentie', '1711-07-07', ['1', '2'])
# ('Advertentie', '1711-07-11', ['1', '2'])
# ('Advertentie', '1711-07-15', ['1', '2'])
# ('Advertentie', '1711-07-17', ['1', '2'])
# ('Advertentie', '1711-07-14', ['1', '2'])
# ('Advertentie', '1711-07-27', ['1', '2'])
# ('Advertentie', '1711-07-03', ['1', '2'])
# ('Advertentie', '1711-07-04', ['1', '2'])
# ('Advertentie', '1711-07-02', ['1', '2'])
# ('Advertentie', '1711-07-01', ['1', '2'])
# ('Advertentie', '1711-07-25', ['1', '2'])
# ('Advertentie', '1711-07-10', ['1', '2'])
# ('Advertentie', '1711-07-20', ['1', '2'])
# ('Advertentie', '1711-07-22', ['1', '2'])
# ('Advertentie', '1711-07-09', ['1', '2'])
# ('Advertentie', '1711-11-12', ['1', '2'])
# ('Advertentie', '1711-11-23', ['1', '2'])
# ('Advertentie', '1711-11-06', ['1', '2'])
# ('Advertentie', '1711-11-28', ['1', '2'])
# ('Advertentie', '1711-11-24', ['1', '2'])
# ('Advertentie', '1711-11-24', ['1', '2'])
# ('Advertentie', '1711-11-26', ['1', '2'])
# ('Advertentie', '1711-11-18', ['1', '2'])
# ('Advertentie', '1711-11-21', ['1', '2'])
# ('Advertentie', '1711-11-21', ['1', '2'])
# ('Advertentie', '1711-11-07', ['1', '2'])
# ('Advertentie', '1711-11-11', ['1', '2'])
# ('Advertentie', '1711-11-17', ['1', '2'])
# ('Advertentie', '1711-11-14', ['1', '2'])
# ('Advertentie', '1711-11-14', ['1', '2'])
# ('Advertentie', '1711-11-27', ['1', '2'])
# ('Advertentie', '1711-11-03', ['1', '2'])
# ('Advertentie', '1711-11-03', ['1', '2'])
# ('Advertentie', '1711-11-04', ['1', '2'])
# ('Advertentie', '1711-11-19', ['1', '2'])
# ('Advertentie', '1711-11-19', ['1', '2'])
# ('Advertentie', '1711-11-25', ['1', '2'])
# ('Advertentie', '1711-11-10', ['1', '2'])
# ('Advertentie', '1711-11-10', ['1', '2'])
# ('Advertentie', '1711-11-05', ['1', '2'])
# ('Advertentie', '1711-11-05', ['1', '2'])
# ('Advertentie', '1711-11-09', ['1', '2'])
# ('Advertentie', '1711-03-12', ['1', '2'])
# ('Advertentie', '1711-03-12', ['1', '2'])
# ('Advertentie', '1711-03-13', ['1', '2'])
# ('Advertentie', '1711-03-31', ['1', '2'])
# ('Advertentie', '1711-03-16', ['1', '2'])
# ('Advertentie', '1711-03-23', ['1', '2'])
# ('Advertentie', '1711-03-06', ['1', '2'])
# ('Advertentie', '1711-03-28', ['1', '2'])
# ('Advertentie', '1711-03-24', ['1', '2'])
# ('Advertentie', '1711-03-26', ['1', '2'])
# ('Advertentie', '1711-03-18', ['1', '2'])
# ('Advertentie', '1711-03-30', ['1', '2'])
# ('Advertentie', '1711-03-21', ['1', '2'])
# ('Advertentie', '1711-03-07', ['1', '2'])
# ('Advertentie', '1711-03-11', ['1', '2'])
# ('Advertentie', '1711-03-17', ['1', '2'])
# ('Advertentie', '1711-03-14', ['1', '2'])
# ('Advertentie', '1711-03-27', ['1', '2'])
# ('Advertentie', '1711-03-03', ['1', '2'])
# ('Advertentie', '1711-03-04', ['1', '2'])
# ('Advertentie', '1711-03-19', ['1', '2'])
# ('Advertentie', '1711-03-02', ['1', '2'])
# ('Advertentie', '1711-03-25', ['1', '2'])
# ('Advertentie', '1711-03-10', ['1', '2'])
# ('Advertentie', '1711-03-10', ['1', '2'])
# ('Advertentie', '1711-03-20', ['1', '2'])
# ('Advertentie', '1711-03-05', ['1', '2'])
# ('Advertentie', '1711-03-05', ['1', '2'])
# ('Advertentie', '1711-03-09', ['1', '2'])
# ('Advertentie', '1711-04-13', ['1', '2'])
# ('Advertentie', '1711-04-16', ['1', '2'])
# ('Advertentie', '1711-04-23', ['1', '2'])
# ('Advertentie', '1711-04-23', ['1', '2'])
# ('Advertentie', '1711-04-06', ['1', '2'])
# ('Advertentie', '1711-04-28', ['1', '2'])
# ('Advertentie', '1711-04-24', ['1', '2'])
# ('Advertentie', '1711-04-29', ['1', '2'])
# ('Advertentie', '1711-04-08', ['1', '2'])
# ('Advertentie', '1711-04-18', ['1', '2'])
# ('Advertentie', '1711-04-30', ['1', '2'])
# ('Advertentie', '1711-04-30', ['1', '2'])
# ('Advertentie', '1711-04-21', ['1', '2'])
# ('Advertentie', '1711-04-21', ['1', '2'])
# ('Advertentie', '1711-04-07', ['1', '2'])
# ('Advertentie', '1711-04-11', ['1', '2'])
# ('Advertentie', '1711-04-15', ['1', '2'])
# ('Advertentie', '1711-04-17', ['1', '2'])
# ('Advertentie', '1711-04-14', ['1', '2'])
# ('Advertentie', '1711-04-27', ['1', '2'])
# ('Advertentie', '1711-04-03', ['1', '2'])
# ('NEDERLANDEN.', '1711-04-04', ['1', '2', '3', '4'])
# ('Advertentie', '1711-04-02', ['1', '2'])
# ('Advertentie', '1711-04-01', ['1', '2'])
# ('Advertentie', '1711-04-25', ['1', '2'])
# ('Advertentie', '1711-04-10', ['1', '2'])
# ('Advertentie', '1711-04-20', ['1', '2'])
# ('Advertentie', '1711-04-22', ['1', '2'])
# ('Advertentie', '1711-04-09', ['1', '2'])
# ('Advertentie', '1711-04-09', ['1', '2'])
# ('Advertentie', '1711-02-12', ['1', '2'])
# ('Advertentie', '1711-02-12', ['1', '2'])
# ('Advertentie', '1711-02-13', ['1', '2'])
# ('Advertentie', '1711-02-16', ['1', '2'])
# ('Advertentie', '1711-02-23', ['1', '2'])
# ('Advertentie', '1711-02-06', ['1', '2'])
# ('Advertentie', '1711-02-28', ['1', '2'])
# ('Advertentie', '1711-02-24', ['1', '2'])
# ('Advertentie', '1711-02-26', ['1', '2'])
# ('Advertentie', '1711-02-18', ['1', '2'])
# ('Advertentie', '1711-02-21', ['1', '2'])
# ('Advertentie', '1711-02-21', ['1', '2'])
# ('NEDERLANDEN.', '1711-02-07', ['1', '2', '3', '4'])
# ('Advertentie', '1711-02-11', ['1', '2'])
# ('Advertentie', '1711-02-17', ['1', '2'])
# ('Advertentie', '1711-02-14', ['1', '2'])
# ('Advertentie', '1711-02-27', ['1', '2'])
# ('Advertentie', '1711-02-03', ['1', '2'])
# ('Advertentie', '1711-02-03', ['1', '2'])
# ('Advertentie', '1711-02-19', ['1', '2'])
# ('Advertentie', '1711-02-02', ['1', '2'])
# ('Advertentie', '1711-02-25', ['1', '2'])
# ('Advertentie', '1711-02-10', ['1', '2'])
# ('Advertentie', '1711-02-10', ['1', '2'])
# ('Advertentie', '1711-02-20', ['1', '2'])
# ('Advertentie', '1711-02-05', ['1', '2'])
# ('Advertentie', '1711-02-09', ['1', '2'])
# ('Advertentie', '1711-01-13', ['1', '2'])
# ('Advertentie', '1711-01-31', ['1', '2'])
# ('Advertentie', '1711-01-16', ['1', '2'])
# ('Advertentie', '1711-01-23', ['1', '2'])
# ('Advertentie', '1711-01-06', ['1', '2'])
# ('Advertentie', '1711-01-28', ['1', '2'])
# ('Advertentie', '1711-01-24', ['1', '2'])
# ('Advertentie', '1711-01-24', ['1', '2'])
# ('Advertentie', '1711-01-29', ['1', '2'])
# ('Advertentie', '1711-01-08', ['1', '2'])
# ('Advertentie', '1711-01-26', ['1', '2'])
# ('Advertentie', '1711-01-30', ['1', '2'])
# ('Advertentie', '1711-01-21', ['1', '2'])
# ('NEDERLANDEN.', '1711-01-15', ['1', '2', '3', '4'])
# ('Advertentie', '1711-01-17', ['1', '2'])
# ('Advertentie', '1711-01-14', ['1', '2'])
# ('Advertentie', '1711-01-27', ['1', '2'])
# ('Advertentie', '1711-01-03', ['1', '2'])
# ('Advertentie', '1711-01-19', ['1', '2'])
# ('Advertentie', '1711-01-01', ['1', '2'])
# ('Advertentie', '1711-01-10', ['1', '2'])
# ('Advertentie', '1711-01-20', ['1', '2'])
# ('Advertentie', '1711-01-22', ['1', '2'])
# ('Advertentie', '1711-10-12', ['1', '2'])
# ('Advertentie', '1711-10-13', ['1', '2'])
# ('Advertentie', '1711-10-31', ['1', '2'])
# ('Advertentie', '1711-10-23', ['1', '2'])
# ('Advertentie', '1711-10-06', ['1', '2'])
# ('Advertentie', '1711-10-06', ['1', '2'])
# ('Advertentie', '1711-10-24', ['1', '2'])
# ('Advertentie', '1711-10-29', ['1', '2'])
# ('Advertentie', '1711-10-29', ['1', '2'])
# ('Advertentie', '1711-10-08', ['1', '2'])
# ('Advertentie', '1711-10-30', ['1', '2'])
# ('Advertentie', '1711-10-07', ['1', '2'])
# ('Advertentie', '1711-10-15', ['1', '2'])
# ('Advertentie', '1711-10-17', ['1', '2'])
# ('Advertentie', '1711-10-14', ['1', '2'])
# ('Advertentie', '1711-10-27', ['1', '2'])
# ('Advertentie', '1711-10-27', ['1', '2'])
# ('Advertentie', '1711-10-03', ['1', '2'])
# ('Advertentie', '1711-10-03', ['1', '2'])
# ('Advertentie', '1711-10-19', ['1', '2'])
# ('Advertentie', '1711-10-01', ['1', '2'])
# ('Advertentie', '1711-10-10', ['1', '2'])
# ('Advertentie', '1711-10-20', ['1', '2'])
# ('Advertentie', '1711-10-05', ['1', '2'])
# ('Advertentie', '1711-10-22', ['1', '2'])
# ('Advertentie', '1711-10-09', ['1', '2'])
# ('NEDERLANDEN.', '1711-05-12', ['1', '2', '1', '2'])
# ('Advertentie', '1711-05-13', ['1', '2'])
# ('NEDERLANDEN.', '1711-05-13', ['3', '4', '1', '2'])
# ('Advertentie', '1711-05-16', ['3', '4'])
# ('Advertentie', '1711-05-23', ['1', '2'])
# ('Advertentie', '1711-05-06', ['1', '2'])
# ('Advertentie', '1711-05-28', ['1', '2'])
# ('Advertentie', '1711-05-29', ['1', '2'])
# ('Advertentie', '1711-05-08', ['1', '2'])
# ('Advertentie', '1711-05-26', ['1', '2'])
# ('Advertentie', '1711-05-18', ['1', '2'])
# ('Advertentie', '1711-05-30', ['1', '2'])
# ('Advertentie', '1711-05-21', ['1', '2'])
# ('Advertentie', '1711-05-07', ['1', '2'])
# ('Advertentie', '1711-05-11', ['1', '2'])
# ('Advertentie', '1711-05-15', ['1', '2'])
# ('Advertentie', '1711-05-27', ['1', '2'])
# ('Advertentie', '1711-05-04', ['1', '2'])
# ('Advertentie', '1711-05-19', ['1', '2'])
# ('Advertentie', '1711-05-02', ['1', '2'])
# ('Advertentie', '1711-05-02', ['1', '2'])
# ('Advertentie', '1711-05-01', ['1', '2'])
# ('Advertentie', '1711-05-25', ['1', '2'])
# ('Advertentie', '1711-05-20', ['1', '2'])
# ('Advertentie', '1711-05-05', ['1', '2'])
# ('Advertentie', '1711-05-05', ['1', '2'])
# ('Advertentie', '1711-05-22', ['1', '2'])
# ('Advertentie', '1711-05-09', ['1', '2'])
# ('Advertentie', '1711-09-12', ['1', '2'])
# ('Advertentie', '1711-09-12', ['1', '2'])
# ('Advertentie', '1711-09-16', ['1', '2'])
# ('Advertentie', '1711-09-23', ['1', '2'])
# ('Advertentie', '1711-09-28', ['1', '2'])
# ('Advertentie', '1711-09-24', ['1', '2'])
# ('Advertentie', '1711-09-29', ['1', '2'])
# ('Advertentie', '1711-09-08', ['1', '2'])
# ('Advertentie', '1711-09-26', ['1', '2'])
# ('Advertentie', '1711-09-18', ['1', '2'])
# ('Advertentie', '1711-09-30', ['1', '2'])
# ('Advertentie', '1711-09-21', ['1', '2'])
# ('NEDERLANDEN.', '1711-09-07', ['1', '2'])
# ('Advertentie', '1711-09-11', ['1', '2'])
# ('Advertentie', '1711-09-15', ['1', '2'])
# ('Advertentie', '1711-09-15', ['1', '2'])
# ('Advertentie', '1711-09-17', ['1', '2'])
# ('Advertentie', '1711-09-17', ['1', '2'])
# ('Advertentie', '1711-09-14', ['1', '2'])
# ('Advertentie', '1711-09-03', ['1', '2'])
# ('Advertentie', '1711-09-04', ['1', '2'])
# ('Advertentie', '1711-09-19', ['1', '2'])
# ('Advertentie', '1711-09-19', ['1', '2'])
# ('Advertentie', '1711-09-02', ['1', '2'])
# ('Advertentie', '1711-09-01', ['1', '2'])
# ('Advertentie', '1711-09-25', ['1', '2'])
# ('Advertentie', '1711-09-10', ['1', '2'])
# ('Advertentie', '1711-09-10', ['1', '2'])
# ('Advertentie', '1711-09-05', ['1', '2'])
# ('Advertentie', '1711-09-22', ['1', '2'])
# ('Advertentie', '1711-09-09', ['1', '2'])
